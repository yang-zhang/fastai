# %% [markdown]
# ## Computer vision

# %%
from fastai.gen_doc.nbdoc import *

# %% [markdown]
# The [`vision`](/vision.html#vision) module of the fastai library contains all the necessary functions to define a Dataset and train a model for computer vision tasks. It contains four different submodules to reach that goal:
# - [`vision.image`](/vision.image.html#vision.image) contains the basic definition of an [`Image`](/vision.image.html#Image) object and all the functions that are used behind the scenes to apply transformations to such an object.
# - [`vision.transform`](/vision.transform.html#vision.transform) contains all the transforms we can use for data augmentation.
# - [`vision.data`](/vision.data.html#vision.data) contains the definition of [`ImageDataBunch`](/vision.data.html#ImageDataBunch) as well as the utility function to easily build a [`DataBunch`](/basic_data.html#DataBunch) for Computer Vision problems.
# - [`vision.learner`](/vision.learner.html#vision.learner) lets you build and fine-tune models with a pretrained CNN backbone or train a randomly initialized model from scratch.
#
# Each of the four module links above includes a quick overview and examples of the functionality of that module, as well as complete API documentation. Below, we'll provide a walk-thru of end to end computer vision model training with the most commonly used functionality.

# %% [markdown]
# ## Minimal training example

# %% [markdown]
# First, import everything you need from the fastai library.

# %%
from fastai.vision import *

# %% [markdown]
# First, create a data folder containing a MNIST subset in `data/mnist_sample` using this little helper that will download it for you:

# %%
path = untar_data(URLs.MNIST_SAMPLE)
path
# Out:
# PosixPath('/home/ubuntu/.fastai/data/mnist_sample')

# %% [markdown]
# Since this contains standard [`train`](/train.html#train) and `valid` folders, and each contains one folder per class, you can create a [`DataBunch`](/basic_data.html#DataBunch) in a single line:

# %%
data = ImageDataBunch.from_folder(path)

# %% [markdown]
# You load a pretrained model (from [`vision.models`](/vision.models.html#vision.models)) ready for fine tuning:

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)

# %% [markdown]
# And now you're ready to train!

# %%
import trace
tracer = trace.Trace(count=True, trace=True)

# %%
# learn.fit(1)
tracer.runfunc(learn.fit, 1)
# Out:
#  --- modulename: basic_train, funcname: fit
# basic_train.py(190):         lr = self.lr_range(lr)
#  --- modulename: basic_train, funcname: lr_range
# basic_train.py(182):         if not isinstance(lr,slice): return lr
# basic_train.py(183):         if lr.start: res = even_mults(lr.start, lr.stop, len(self.layer_groups))
# basic_train.py(184):         else: res = [lr.stop/10]*(len(self.layer_groups)-1) + [lr.stop]
# basic_train.py(185):         return np.array(res)
# basic_train.py(191):         if wd is None: wd = self.wd
# basic_train.py(192):         if not getattr(self, 'opt', False): self.create_opt(lr, wd)
# basic_train.py(193):         else: self.opt.lr,self.opt.wd = lr,wd
#  --- modulename: callback, funcname: lr
# callback.py(80):         self._lr = self.set_val('lr', listify(val, self._lr))
#  --- modulename: core, funcname: listify
# core.py(104):     if p is None: p=[]
# core.py(105):     elif isinstance(p, str):          p = [p]
# core.py(106):     elif not isinstance(p, Iterable): p = [p]
#  --- modulename: abc, funcname: __instancecheck__
# abc.py(139):             return _abc_instancecheck(cls, instance)
#  --- modulename: abc, funcname: __subclasscheck__
# abc.py(143):             return _abc_subclasscheck(cls, subclass)
#  --- modulename: _collections_abc, funcname: __subclasshook__
# _collections_abc.py(254):         if cls is Iterable:
# _collections_abc.py(255):             return _check_methods(C, "__iter__")
#  --- modulename: _collections_abc, funcname: _check_methods
# _collections_abc.py(73):     mro = C.__mro__
# _collections_abc.py(74):     for method in methods:
# _collections_abc.py(75):         for B in mro:
# _collections_abc.py(76):             if method in B.__dict__:
# _collections_abc.py(77):                 if B.__dict__[method] is None:
# _collections_abc.py(79):                 break
# _collections_abc.py(74):     for method in methods:
# _collections_abc.py(82):     return True
# core.py(109):         try: a = len(p)
# core.py(111):     n = q if type(q)==int else len(p) if q is None else len(q)
# core.py(112):     if len(p)==1: p = p * n
# core.py(113):     assert len(p)==n, f'List len mismatch ({len(p)} vs {n})'
# core.py(114):     return list(p)
#  --- modulename: callback, funcname: set_val
# callback.py(133):         if is_tuple(val): val = [(v1,v2) for v1,v2 in zip(*val)]
#  --- modulename: core, funcname: is_tuple
# core.py(52): def is_tuple(x:Any)->bool: return isinstance(x, tuple)
# callback.py(134):         for v,pg1,pg2 in zip(val,self.opt.param_groups[::2],self.opt.param_groups[1::2]):
# callback.py(135):             pg1[key] = v
# callback.py(136):             if bn_groups: pg2[key] = v
# callback.py(134):         for v,pg1,pg2 in zip(val,self.opt.param_groups[::2],self.opt.param_groups[1::2]):
# callback.py(135):             pg1[key] = v
# callback.py(136):             if bn_groups: pg2[key] = v
# callback.py(134):         for v,pg1,pg2 in zip(val,self.opt.param_groups[::2],self.opt.param_groups[1::2]):
# callback.py(135):             pg1[key] = v
# callback.py(136):             if bn_groups: pg2[key] = v
# callback.py(134):         for v,pg1,pg2 in zip(val,self.opt.param_groups[::2],self.opt.param_groups[1::2]):
# callback.py(137):         return val
#  --- modulename: callback, funcname: wd
# callback.py(105):         if not self.true_wd: self.set_val('weight_decay', listify(val, self._wd), bn_groups=self.bn_wd)
# callback.py(106):         self._wd = listify(val, self._wd)
#  --- modulename: core, funcname: listify
# core.py(104):     if p is None: p=[]
# core.py(105):     elif isinstance(p, str):          p = [p]
# core.py(106):     elif not isinstance(p, Iterable): p = [p]
#  --- modulename: abc, funcname: __instancecheck__
# abc.py(139):             return _abc_instancecheck(cls, instance)
# core.py(111):     n = q if type(q)==int else len(p) if q is None else len(q)
# core.py(112):     if len(p)==1: p = p * n
# core.py(113):     assert len(p)==n, f'List len mismatch ({len(p)} vs {n})'
# core.py(114):     return list(p)
# basic_train.py(194):         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#  --- modulename: basic_train, funcname: <listcomp>
# basic_train.py(194):         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#  --- modulename: basic_train, funcname: __init__
# basic_train.py(437):         super().__init__(learn)
#  --- modulename: basic_train, funcname: __init__
# basic_train.py(418):         self._learn = weakref.ref(learn)
# basic_train.py(419):         self.exclude,self.not_min = ['_learn'],[]
# basic_train.py(420):         setattr(self.learn, self.cb_name, self)
#  --- modulename: basic_train, funcname: learn
# basic_train.py(426):     def learn(self) -> Learner: return self._learn()
#  --- modulename: basic_train, funcname: cb_name
# basic_train.py(431):     def cb_name(self): return camel2snake(self.__class__.__name__)
#  --- modulename: core, funcname: camel2snake
# core.py(120):     s1 = re.sub(_camel_re1, r'\1_\2', name)
#  --- modulename: re, funcname: sub
# re.py(192):     return _compile(pattern, flags).sub(repl, string, count)
#  --- modulename: re, funcname: _compile
# re.py(273):     if isinstance(flags, RegexFlag):
# re.py(275):     try:
# re.py(276):         return _cache[type(pattern), pattern, flags]
# re.py(277):     except KeyError:
# re.py(278):         pass
# re.py(279):     if isinstance(pattern, Pattern):
# re.py(280):         if flags:
# re.py(283):         return pattern
#  --- modulename: re, funcname: _subx
# re.py(309):     template = _compile_repl(template, pattern)
#  --- modulename: re, funcname: _compile_repl
# re.py(300):     return sre_parse.parse_template(repl, pattern)
#  --- modulename: sre_parse, funcname: parse_template
# sre_parse.py(954):     s = Tokenizer(source)
#  --- modulename: sre_parse, funcname: __init__
# sre_parse.py(225):         self.istext = isinstance(string, str)
# sre_parse.py(226):         self.string = string
# sre_parse.py(227):         if not self.istext:
# sre_parse.py(229):         self.decoded_string = string
# sre_parse.py(230):         self.index = 0
# sre_parse.py(231):         self.next = None
# sre_parse.py(232):         self.__next()
#  --- modulename: sre_parse, funcname: __next
# sre_parse.py(234):         index = self.index
# sre_parse.py(235):         try:
# sre_parse.py(236):             char = self.decoded_string[index]
# sre_parse.py(240):         if char == "\\":
# sre_parse.py(241):             index += 1
# sre_parse.py(242):             try:
# sre_parse.py(243):                 char += self.decoded_string[index]
# sre_parse.py(247):         self.index = index + 1
# sre_parse.py(248):         self.next = char
# sre_parse.py(955):     sget = s.get
# sre_parse.py(956):     groups = []
# sre_parse.py(957):     literals = []
# sre_parse.py(958):     literal = []
# sre_parse.py(959):     lappend = literal.append
# sre_parse.py(960):     def addgroup(index, pos):
# sre_parse.py(968):     groupindex = pattern.groupindex
# sre_parse.py(969):     while True:
# sre_parse.py(970):         this = sget()
#  --- modulename: sre_parse, funcname: get
# sre_parse.py(255):         this = self.next
# sre_parse.py(256):         self.__next()
#  --- modulename: sre_parse, funcname: __next
# sre_parse.py(234):         index = self.index
# sre_parse.py(235):         try:
# sre_parse.py(236):             char = self.decoded_string[index]
# sre_parse.py(240):         if char == "\\":
# sre_parse.py(247):         self.index = index + 1
# sre_parse.py(248):         self.next = char
# sre_parse.py(257):         return this
# sre_parse.py(971):         if this is None:
# sre_parse.py(973):         if this[0] == "\\":
# sre_parse.py(975):             c = this[1]
# sre_parse.py(976):             if c == "g":
# sre_parse.py(998):             elif c == "0":
# sre_parse.py(1004):             elif c in DIGITS:
# sre_parse.py(1005):                 isoctal = False
# sre_parse.py(1006):                 if s.next in DIGITS:
# sre_parse.py(1017):                 if not isoctal:
# sre_parse.py(1018):                     addgroup(int(this[1:]), len(this) - 1)
#  --- modulename: sre_parse, funcname: addgroup
# sre_parse.py(961):         if index > pattern.groups:
# sre_parse.py(963):         if literal:
# sre_parse.py(966):         groups.append((len(literals), index))
# sre_parse.py(967):         literals.append(None)
# sre_parse.py(970):         this = sget()
#  --- modulename: sre_parse, funcname: get
# sre_parse.py(255):         this = self.next
# sre_parse.py(256):         self.__next()
#  --- modulename: sre_parse, funcname: __next
# sre_parse.py(234):         index = self.index
# sre_parse.py(235):         try:
# sre_parse.py(236):             char = self.decoded_string[index]
# sre_parse.py(240):         if char == "\\":
# sre_parse.py(241):             index += 1
# sre_parse.py(242):             try:
# sre_parse.py(243):                 char += self.decoded_string[index]
# sre_parse.py(247):         self.index = index + 1
# sre_parse.py(248):         self.next = char
# sre_parse.py(257):         return this
# sre_parse.py(971):         if this is None:
# sre_parse.py(973):         if this[0] == "\\":
# sre_parse.py(1027):             lappend(this)
# sre_parse.py(970):         this = sget()
#  --- modulename: sre_parse, funcname: get
# sre_parse.py(255):         this = self.next
# sre_parse.py(256):         self.__next()
#  --- modulename: sre_parse, funcname: __next
# sre_parse.py(234):         index = self.index
# sre_parse.py(235):         try:
# sre_parse.py(236):             char = self.decoded_string[index]
# sre_parse.py(237):         except IndexError:
# sre_parse.py(238):             self.next = None
# sre_parse.py(239):             return
# sre_parse.py(257):         return this
# sre_parse.py(971):         if this is None:
# sre_parse.py(973):         if this[0] == "\\":
# sre_parse.py(975):             c = this[1]
# sre_parse.py(976):             if c == "g":
# sre_parse.py(998):             elif c == "0":
# sre_parse.py(1004):             elif c in DIGITS:
# sre_parse.py(1005):                 isoctal = False
# sre_parse.py(1006):                 if s.next in DIGITS:
# sre_parse.py(1017):                 if not isoctal:
# sre_parse.py(1018):                     addgroup(int(this[1:]), len(this) - 1)
#  --- modulename: sre_parse, funcname: addgroup
# sre_parse.py(961):         if index > pattern.groups:
# sre_parse.py(963):         if literal:
# sre_parse.py(964):             literals.append(''.join(literal))
# sre_parse.py(965):             del literal[:]
# sre_parse.py(966):         groups.append((len(literals), index))
# sre_parse.py(967):         literals.append(None)
# sre_parse.py(970):         this = sget()
#  --- modulename: sre_parse, funcname: get
# sre_parse.py(255):         this = self.next
# sre_parse.py(256):         self.__next()
#  --- modulename: sre_parse, funcname: __next
# sre_parse.py(234):         index = self.index
# sre_parse.py(235):         try:
# sre_parse.py(236):             char = self.decoded_string[index]
# sre_parse.py(237):         except IndexError:
# sre_parse.py(238):             self.next = None
# sre_parse.py(239):             return
# sre_parse.py(257):         return this
# sre_parse.py(971):         if this is None:
# sre_parse.py(972):             break # end of replacement string
# sre_parse.py(1028):     if literal:
# sre_parse.py(1030):     if not isinstance(source, str):
# sre_parse.py(1034):     return groups, literals
# re.py(310):     if not template[0] and len(template[1]) == 1:
# re.py(313):     def filter(match, template=template):
# re.py(315):     return filter
# core.py(121):     return re.sub(_camel_re2, r'\1_\2', s1).lower()
#  --- modulename: re, funcname: sub
# re.py(192):     return _compile(pattern, flags).sub(repl, string, count)
#  --- modulename: re, funcname: _compile
# re.py(273):     if isinstance(flags, RegexFlag):
# re.py(275):     try:
# re.py(276):         return _cache[type(pattern), pattern, flags]
# re.py(277):     except KeyError:
# re.py(278):         pass
# re.py(279):     if isinstance(pattern, Pattern):
# re.py(280):         if flags:
# re.py(283):         return pattern
#  --- modulename: re, funcname: _subx
# re.py(309):     template = _compile_repl(template, pattern)
#  --- modulename: re, funcname: _compile_repl
# re.py(300):     return sre_parse.parse_template(repl, pattern)
#  --- modulename: sre_parse, funcname: parse_template
# sre_parse.py(954):     s = Tokenizer(source)
#  --- modulename: sre_parse, funcname: __init__
# sre_parse.py(225):         self.istext = isinstance(string, str)
# sre_parse.py(226):         self.string = string
# sre_parse.py(227):         if not self.istext:
# sre_parse.py(229):         self.decoded_string = string
# sre_parse.py(230):         self.index = 0
# sre_parse.py(231):         self.next = None
# sre_parse.py(232):         self.__next()
#  --- modulename: sre_parse, funcname: __next
# sre_parse.py(234):         index = self.index
# sre_parse.py(235):         try:
# sre_parse.py(236):             char = self.decoded_string[index]
# sre_parse.py(240):         if char == "\\":
# sre_parse.py(241):             index += 1
# sre_parse.py(242):             try:
# sre_parse.py(243):                 char += self.decoded_string[index]
# sre_parse.py(247):         self.index = index + 1
# sre_parse.py(248):         self.next = char
# sre_parse.py(955):     sget = s.get
# sre_parse.py(956):     groups = []
# sre_parse.py(957):     literals = []
# sre_parse.py(958):     literal = []
# sre_parse.py(959):     lappend = literal.append
# sre_parse.py(960):     def addgroup(index, pos):
# sre_parse.py(968):     groupindex = pattern.groupindex
# sre_parse.py(969):     while True:
# sre_parse.py(970):         this = sget()
#  --- modulename: sre_parse, funcname: get
# sre_parse.py(255):         this = self.next
# sre_parse.py(256):         self.__next()
#  --- modulename: sre_parse, funcname: __next
# sre_parse.py(234):         index = self.index
# sre_parse.py(235):         try:
# sre_parse.py(236):             char = self.decoded_string[index]
# sre_parse.py(240):         if char == "\\":
# sre_parse.py(247):         self.index = index + 1
# sre_parse.py(248):         self.next = char
# sre_parse.py(257):         return this
# sre_parse.py(971):         if this is None:
# sre_parse.py(973):         if this[0] == "\\":
# sre_parse.py(975):             c = this[1]
# sre_parse.py(976):             if c == "g":
# sre_parse.py(998):             elif c == "0":
# sre_parse.py(1004):             elif c in DIGITS:
# sre_parse.py(1005):                 isoctal = False
# sre_parse.py(1006):                 if s.next in DIGITS:
# sre_parse.py(1017):                 if not isoctal:
# sre_parse.py(1018):                     addgroup(int(this[1:]), len(this) - 1)
#  --- modulename: sre_parse, funcname: addgroup
# sre_parse.py(961):         if index > pattern.groups:
# sre_parse.py(963):         if literal:
# sre_parse.py(966):         groups.append((len(literals), index))
# sre_parse.py(967):         literals.append(None)
# sre_parse.py(970):         this = sget()
#  --- modulename: sre_parse, funcname: get
# sre_parse.py(255):         this = self.next
# sre_parse.py(256):         self.__next()
#  --- modulename: sre_parse, funcname: __next
# sre_parse.py(234):         index = self.index
# sre_parse.py(235):         try:
# sre_parse.py(236):             char = self.decoded_string[index]
# sre_parse.py(240):         if char == "\\":
# sre_parse.py(241):             index += 1
# sre_parse.py(242):             try:
# sre_parse.py(243):                 char += self.decoded_string[index]
# sre_parse.py(247):         self.index = index + 1
# sre_parse.py(248):         self.next = char
# sre_parse.py(257):         return this
# sre_parse.py(971):         if this is None:
# sre_parse.py(973):         if this[0] == "\\":
# sre_parse.py(1027):             lappend(this)
# sre_parse.py(970):         this = sget()
#  --- modulename: sre_parse, funcname: get
# sre_parse.py(255):         this = self.next
# sre_parse.py(256):         self.__next()
#  --- modulename: sre_parse, funcname: __next
# sre_parse.py(234):         index = self.index
# sre_parse.py(235):         try:
# sre_parse.py(236):             char = self.decoded_string[index]
# sre_parse.py(237):         except IndexError:
# sre_parse.py(238):             self.next = None
# sre_parse.py(239):             return
# sre_parse.py(257):         return this
# sre_parse.py(971):         if this is None:
# sre_parse.py(973):         if this[0] == "\\":
# sre_parse.py(975):             c = this[1]
# sre_parse.py(976):             if c == "g":
# sre_parse.py(998):             elif c == "0":
# sre_parse.py(1004):             elif c in DIGITS:
# sre_parse.py(1005):                 isoctal = False
# sre_parse.py(1006):                 if s.next in DIGITS:
# sre_parse.py(1017):                 if not isoctal:
# sre_parse.py(1018):                     addgroup(int(this[1:]), len(this) - 1)
#  --- modulename: sre_parse, funcname: addgroup
# sre_parse.py(961):         if index > pattern.groups:
# sre_parse.py(963):         if literal:
# sre_parse.py(964):             literals.append(''.join(literal))
# sre_parse.py(965):             del literal[:]
# sre_parse.py(966):         groups.append((len(literals), index))
# sre_parse.py(967):         literals.append(None)
# sre_parse.py(970):         this = sget()
#  --- modulename: sre_parse, funcname: get
# sre_parse.py(255):         this = self.next
# sre_parse.py(256):         self.__next()
#  --- modulename: sre_parse, funcname: __next
# sre_parse.py(234):         index = self.index
# sre_parse.py(235):         try:
# sre_parse.py(236):             char = self.decoded_string[index]
# sre_parse.py(237):         except IndexError:
# sre_parse.py(238):             self.next = None
# sre_parse.py(239):             return
# sre_parse.py(257):         return this
# sre_parse.py(971):         if this is None:
# sre_parse.py(972):             break # end of replacement string
# sre_parse.py(1028):     if literal:
# sre_parse.py(1030):     if not isinstance(source, str):
# sre_parse.py(1034):     return groups, literals
# re.py(310):     if not template[0] and len(template[1]) == 1:
# re.py(313):     def filter(match, template=template):
# re.py(315):     return filter
# basic_train.py(438):         self.opt = self.learn.opt
#  --- modulename: basic_train, funcname: learn
# basic_train.py(426):     def learn(self) -> Learner: return self._learn()
# basic_train.py(439):         self.train_dl = self.learn.data.train_dl
#  --- modulename: basic_train, funcname: learn
# basic_train.py(426):     def learn(self) -> Learner: return self._learn()
# basic_train.py(440):         self.no_val,self.silent,self.add_time = False,False,add_time
# basic_train.py(194):         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#  --- modulename: core, funcname: listify
# core.py(104):     if p is None: p=[]
# core.py(111):     n = q if type(q)==int else len(p) if q is None else len(q)
# core.py(112):     if len(p)==1: p = p * n
# core.py(113):     assert len(p)==n, f'List len mismatch ({len(p)} vs {n})'
# core.py(114):     return list(p)
# basic_train.py(195):         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
# basic_train.py(196):         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#  --- modulename: basic_train, funcname: fit
# basic_train.py(86):     assert len(learn.data.train_dl) != 0, f"""Your training dataloader is empty, can't train a model.
#  --- modulename: basic_data, funcname: __len__
# basic_data.py(37):     def __len__(self)->int: return len(self.dl)
#  --- modulename: dataloader, funcname: __len__
# dataloader.py(822):         return len(self.batch_sampler)
#  --- modulename: sampler, funcname: __len__
# sampler.py(169):         if self.drop_last:
# sampler.py(170):             return len(self.sampler) // self.batch_size
#  --- modulename: sampler, funcname: __len__
# sampler.py(76):         return len(self.data_source)
#  --- modulename: data_block, funcname: __len__
# data_block.py(591):     def __len__(self)->int: return len(self.x) if self.item is None else 1
#  --- modulename: data_block, funcname: __len__
# data_block.py(63):     def __len__(self)->int: return len(self.items) or 1
# basic_train.py(88):     cb_handler = CallbackHandler(callbacks, metrics)
#  --- modulename: callback, funcname: __post_init__
# callback.py(231):         self.callbacks = ifnone(self.callbacks, [])
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# callback.py(232):         self.metrics = ifnone(self.metrics, [])
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# callback.py(233):         self.metrics = [(met if isinstance(met, Callback) else AverageMetric(met)) for met in self.metrics]
#  --- modulename: callback, funcname: <listcomp>
# callback.py(233):         self.metrics = [(met if isinstance(met, Callback) else AverageMetric(met)) for met in self.metrics]
#  --- modulename: callback, funcname: __init__
# callback.py(328):         name = getattr(func,'func', func).__name__
# callback.py(329):         self.func, self.name = func, name
# callback.py(330):         self.world = num_distrib()
#  --- modulename: torch_core, funcname: num_distrib
# torch_core.py(395):     return int(os.environ.get('WORLD_SIZE', 0))
#  --- modulename: _collections_abc, funcname: get
# _collections_abc.py(659):         try:
# _collections_abc.py(660):             return self[key]
#  --- modulename: os, funcname: __getitem__
# os.py(674):         try:
# os.py(675):             value = self._data[self.encodekey(key)]
#  --- modulename: os, funcname: encode
# os.py(752):             if not isinstance(value, str):
# os.py(754):             return value.encode(encoding, 'surrogateescape')
# os.py(676):         except KeyError:
# os.py(678):             raise KeyError(key) from None
# _collections_abc.py(661):         except KeyError:
# _collections_abc.py(662):             return default
# callback.py(233):         self.metrics = [(met if isinstance(met, Callback) else AverageMetric(met)) for met in self.metrics]
# callback.py(234):         self.callbacks = sorted(self.callbacks, key=lambda o: getattr(o, '_order', 0))
#  --- modulename: callback, funcname: <lambda>
# callback.py(234):         self.callbacks = sorted(self.callbacks, key=lambda o: getattr(o, '_order', 0))
# callback.py(235):         self.smoothener = SmoothenValue(self.beta)
#  --- modulename: callback, funcname: __init__
# callback.py(210):         self.beta,self.n,self.mov_avg = beta,0,0
# callback.py(236):         self.state_dict:Dict[str,Union[int,float,Tensor]]=_get_init_state()
#  --- modulename: callback, funcname: _get_init_state
# callback.py(220): def _get_init_state(): return {'epoch':0, 'iteration':0, 'num_batch':0}
# basic_train.py(89):     pbar = master_bar(range(epochs))
#  --- modulename: fastprogress, funcname: __init__
# fastprogress.py(175):         super().__init__(gen, NBProgressBar, total)
#  --- modulename: fastprogress, funcname: __init__
# fastprogress.py(102):     def __init__(self, gen, cls, total=None): self.first_bar = cls(gen, total=total, display=False)
#  --- modulename: fastprogress, funcname: __init__
# fastprogress.py(151):         self.progress = html_progress_bar(0, len(gen) if total is None else total, "")
#  --- modulename: fastprogress, funcname: html_progress_bar
# fastprogress.py(116):     bar_style = 'progress-bar-interrupted' if interrupted else ''
# fastprogress.py(134):     """
# fastprogress.py(152):         super().__init__(gen, total, display, leave, parent, auto_update)
#  --- modulename: fastprogress, funcname: __init__
# fastprogress.py(44):         self._gen = gen
# fastprogress.py(45):         self.auto_update = auto_update
# fastprogress.py(46):         self.total = len(gen) if total is None else total
# fastprogress.py(47):         self.parent = parent
# fastprogress.py(48):         if parent is None: self.leave,self.display = leave,display
# fastprogress.py(52):         self.comment = ''
# fastprogress.py(53):         if not self.auto_update:
# fastprogress.py(176):         self.report, self.clean_on_interrupt = [], clean_on_interrupt
# fastprogress.py(177):         self.text,self.lines = "",[]
# fastprogress.py(178):         self.html_code = '\n'.join([self.first_bar.progress, self.text])
# fastprogress.py(179):         if order is None: order = ['pb1', 'text', 'pb2']
# fastprogress.py(180):         self.inner_dict = {'pb1':self.first_bar.progress, 'text':self.text}
# fastprogress.py(181):         self.hide_graph,self.order = hide_graph,order
# basic_train.py(90):     cb_handler.on_train_begin(epochs, pbar=pbar, metrics=metrics)
#  --- modulename: callback, funcname: on_train_begin
# callback.py(261):         self.state_dict = _get_init_state()
#  --- modulename: callback, funcname: _get_init_state
# callback.py(220): def _get_init_state(): return {'epoch':0, 'iteration':0, 'num_batch':0}
# callback.py(262):         self.state_dict.update(dict(n_epochs=epochs, pbar=pbar, metrics=metrics))
# callback.py(263):         names = [(met.name if hasattr(met, 'name') else camel2snake(met.__class__.__name__)) for met in self.metrics]
#  --- modulename: callback, funcname: <listcomp>
# callback.py(263):         names = [(met.name if hasattr(met, 'name') else camel2snake(met.__class__.__name__)) for met in self.metrics]
# callback.py(263):         names = [(met.name if hasattr(met, 'name') else camel2snake(met.__class__.__name__)) for met in self.metrics]
# callback.py(264):         self('train_begin', metrics_names=names)
#  --- modulename: callback, funcname: __call__
# callback.py(248):         if call_mets:
# callback.py(249):             for met in self.metrics: self._call_and_update(met, cb_name, **kwargs)
#  --- modulename: callback, funcname: _call_and_update
# callback.py(240):         new = ifnone(getattr(cb, f'on_{cb_name}')(**self.state_dict, **kwargs), dict())
#  --- modulename: callback, funcname: on_train_begin
# callback.py(163):         pass
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# callback.py(241):         for k,v in new.items():
# callback.py(249):             for met in self.metrics: self._call_and_update(met, cb_name, **kwargs)
# callback.py(250):         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
#  --- modulename: callback, funcname: _call_and_update
# callback.py(240):         new = ifnone(getattr(cb, f'on_{cb_name}')(**self.state_dict, **kwargs), dict())
#  --- modulename: basic_train, funcname: on_train_begin
# basic_train.py(444):         self.pbar = pbar
# basic_train.py(445):         self.names = ['epoch', 'train_loss'] if self.no_val else ['epoch', 'train_loss', 'valid_loss']
# basic_train.py(446):         self.names += metrics_names
# basic_train.py(447):         if hasattr(self, '_added_met_names'): self.names += self._added_met_names
#  --- modulename: basic_train, funcname: __getattr__
# basic_train.py(422):     def __getattr__(self,k): return getattr(self.learn, k)
#  --- modulename: basic_train, funcname: learn
# basic_train.py(426):     def learn(self) -> Learner: return self._learn()
# basic_train.py(448):         if self.add_time: self.names.append('time')
# basic_train.py(449):         if not self.silent: self.pbar.write(self.names, table=True)
#  --- modulename: fastprogress, funcname: write
# fastprogress.py(211):         if not table: self.text += line + "<p>"
# fastprogress.py(213):             self.lines.append(line)
# fastprogress.py(214):             self.text = text2html_table(self.lines)
#  --- modulename: fastprogress, funcname: text2html_table
# fastprogress.py(138):     html_code = f"""<table border="1" class="dataframe">\n"""
# fastprogress.py(139):     html_code += f"""  <thead>\n    <tr style="text-align: left;">\n"""
# fastprogress.py(140):     for i in items[0]: html_code += f"      <th>{i}</th>\n"
# fastprogress.py(140):     for i in items[0]: html_code += f"      <th>{i}</th>\n"
# fastprogress.py(140):     for i in items[0]: html_code += f"      <th>{i}</th>\n"
# fastprogress.py(140):     for i in items[0]: html_code += f"      <th>{i}</th>\n"
# fastprogress.py(140):     for i in items[0]: html_code += f"      <th>{i}</th>\n"
# fastprogress.py(140):     for i in items[0]: html_code += f"      <th>{i}</th>\n"
# fastprogress.py(141):     html_code += f"    </tr>\n  </thead>\n  <tbody>\n"
# fastprogress.py(142):     for line in items[1:]:
# fastprogress.py(146):     html_code += "  </tbody>\n</table><p>"
# fastprogress.py(147):     return html_code
# basic_train.py(450):         self.losses,self.val_losses,self.lrs,self.moms,self.metrics,self.nb_batches = [],[],[],[],[],[]
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# callback.py(241):         for k,v in new.items():
# callback.py(250):         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
# callback.py(265):         if self.state_dict['epoch'] != 0:
# basic_train.py(92):     exception=False
# basic_train.py(93):     try:
# basic_train.py(94):         for epoch in pbar:
#  --- modulename: fastprogress, funcname: __iter__
# fastprogress.py(105):         self.on_iter_begin()
#  --- modulename: fastprogress, funcname: on_iter_begin
# fastprogress.py(184):         super().on_iter_begin()
#  --- modulename: fastprogress, funcname: on_iter_begin
# fastprogress.py(109):     def on_iter_begin(self): self.start_t = time()
# fastprogress.py(185):         self.out = display(HTML(self.html_code), display_id=True)
#  --- modulename: display, funcname: __init__
# display.py(676):         def warn():
# display.py(688):         if warn():
#  --- modulename: display, funcname: warn
# display.py(677):             if not data:
# display.py(684):             prefix = data[:10].lower()
# display.py(685):             suffix = data[-10:].lower()
# display.py(686):             return prefix.startswith("<iframe ") and suffix.endswith("</iframe>")
# display.py(690):         super(HTML, self).__init__(data=data, url=url, filename=filename, metadata=metadata)
#  --- modulename: display, funcname: __init__
# display.py(596):         if data is not None and isinstance(data, str):
# display.py(597):             if data.startswith('http') and url is None:
# display.py(601):             elif _safe_exists(data) and filename is None:
#  --- modulename: display, funcname: _safe_exists
# display.py(34):     try:
# display.py(35):         return os.path.exists(path)
#  --- modulename: genericpath, funcname: exists
# genericpath.py(18):     try:
# genericpath.py(19):         os.stat(path)
# genericpath.py(20):     except OSError:
# genericpath.py(21):         return False
# display.py(606):         self.data = data
# display.py(607):         self.url = url
# display.py(608):         self.filename = filename
# display.py(610):         if metadata is not None:
# display.py(612):         elif self.metadata is None:
# display.py(613):             self.metadata = {}
# display.py(615):         self.reload()
#  --- modulename: display, funcname: reload
# display.py(639):         if self.filename is not None:
# display.py(642):         elif self.url is not None:
# display.py(616):         self._check_data()
#  --- modulename: display, funcname: _check_data
# display.py(664):         if self.data is not None and not isinstance(self.data, str):
#  --- modulename: display, funcname: display
# display.py(276):     from IPython.core.interactiveshell import InteractiveShell
#  --- modulename: _bootstrap, funcname: _handle_fromlist
# <frozen importlib._bootstrap>(1019): <frozen importlib._bootstrap>(1044): display.py(278):     if not InteractiveShell.initialized():
#  --- modulename: configurable, funcname: initialized
# configurable.py(429):         return hasattr(cls, "_instance") and cls._instance is not None
# display.py(283):     raw = kwargs.pop('raw', False)
# display.py(284):     if transient is None:
# display.py(285):         transient = {}
# display.py(286):     if metadata is None:
# display.py(287):         metadata={}
# display.py(288):     if display_id:
# display.py(289):         if display_id is True:
# display.py(290):             display_id = _new_id()
#  --- modulename: display, funcname: _new_id
# display.py(126):     return b2a_hex(os.urandom(16)).decode('ascii')
# display.py(291):         transient['display_id'] = display_id
# display.py(292):     if kwargs.get('update') and 'display_id' not in transient:
# display.py(294):     if transient:
# display.py(295):         kwargs['transient'] = transient
# display.py(297):     if not raw:
# display.py(298):         format = InteractiveShell.instance().display_formatter.format
#  --- modulename: configurable, funcname: instance
# configurable.py(411):         if cls._instance is None:
# configurable.py(418):         if isinstance(cls._instance, cls):
# configurable.py(419):             return cls._instance
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# display.py(300):     for obj in objs:
# display.py(301):         if raw:
# display.py(304):             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#  --- modulename: formatters, funcname: format
# formatters.py(143):         format_dict = {}
# formatters.py(144):         md_dict = {}
# formatters.py(146):         if self.ipython_display_formatter(obj):
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: formatters, funcname: catch_format_error
# formatters.py(223):     try:
# formatters.py(224):         r = method(self, *args, **kwargs)
#  --- modulename: formatters, funcname: __call__
# formatters.py(906):         if self.enabled:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# formatters.py(908):             try:
# formatters.py(909):                 printer = self.lookup(obj)
#  --- modulename: formatters, funcname: lookup
# formatters.py(391):         obj_id = id(obj)
# formatters.py(392):         if obj_id in self.singleton_printers:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# formatters.py(395):         return self.lookup_by_type(_get_type(obj))
#  --- modulename: formatters, funcname: _get_type
# formatters.py(276):     return getattr(obj, '__class__', None) or type(obj)
#  --- modulename: formatters, funcname: lookup_by_type
# formatters.py(413):         if isinstance(typ, str):
# formatters.py(424):             for cls in pretty._get_mro(typ):
#  --- modulename: pretty, funcname: _get_mro
# pretty.py(317):     if not hasattr(obj_class, '__mro__'):
# pretty.py(328):         mro = obj_class.__mro__
# pretty.py(329):     return mro
# formatters.py(425):                 if cls in self.type_printers or self._in_deferred_types(cls):
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: formatters, funcname: _in_deferred_types
# formatters.py(556):         mod = getattr(cls, '__module__', None)
# formatters.py(557):         name = getattr(cls, '__name__', None)
# formatters.py(558):         key = (mod, name)
# formatters.py(559):         if key in self.deferred_printers:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# formatters.py(564):         return False
# formatters.py(424):             for cls in pretty._get_mro(typ):
# formatters.py(425):                 if cls in self.type_printers or self._in_deferred_types(cls):
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: formatters, funcname: _in_deferred_types
# formatters.py(556):         mod = getattr(cls, '__module__', None)
# formatters.py(557):         name = getattr(cls, '__name__', None)
# formatters.py(558):         key = (mod, name)
# formatters.py(559):         if key in self.deferred_printers:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# formatters.py(564):         return False
# formatters.py(424):             for cls in pretty._get_mro(typ):
# formatters.py(425):                 if cls in self.type_printers or self._in_deferred_types(cls):
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: formatters, funcname: _in_deferred_types
# formatters.py(556):         mod = getattr(cls, '__module__', None)
# formatters.py(557):         name = getattr(cls, '__name__', None)
# formatters.py(558):         key = (mod, name)
# formatters.py(559):         if key in self.deferred_printers:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# formatters.py(564):         return False
# formatters.py(424):             for cls in pretty._get_mro(typ):
# formatters.py(425):                 if cls in self.type_printers or self._in_deferred_types(cls):
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: formatters, funcname: _in_deferred_types
# formatters.py(556):         mod = getattr(cls, '__module__', None)
# formatters.py(557):         name = getattr(cls, '__name__', None)
# formatters.py(558):         key = (mod, name)
# formatters.py(559):         if key in self.deferred_printers:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# formatters.py(564):         return False
# formatters.py(424):             for cls in pretty._get_mro(typ):
# formatters.py(429):         raise KeyError("No registered printer for {0!r}".format(typ))
# formatters.py(910):             except KeyError:
# formatters.py(911):                 pass
# formatters.py(916):             method = get_real_method(obj, self.print_method)
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: dir2, funcname: get_real_method
# dir2.py(64):     try:
# dir2.py(65):         canary = getattr(obj, '_ipython_canary_method_should_not_exist_', None)
# dir2.py(69):     if canary is not None:
# dir2.py(73):     try:
# dir2.py(74):         m = getattr(obj, name, None)
# dir2.py(78):     if inspect.isclass(obj) and not isinstance(m, types.MethodType):
#  --- modulename: inspect, funcname: isclass
# inspect.py(78):     return isinstance(object, type)
# dir2.py(81):     if callable(m):
# dir2.py(84):     return None
# formatters.py(917):             if method is not None:
# formatters.py(236):     return self._check_return(r, args[0])
#  --- modulename: formatters, funcname: _check_return
# formatters.py(364):         if r is None or isinstance(r, self._return_type) or \
# formatters.py(366):             return r
# formatters.py(150):         format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: formatters, funcname: catch_format_error
# formatters.py(223):     try:
# formatters.py(224):         r = method(self, *args, **kwargs)
#  --- modulename: formatters, funcname: __call__
# formatters.py(958):         if self.enabled:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# formatters.py(960):             try:
# formatters.py(961):                 printer = self.lookup(obj)
#  --- modulename: formatters, funcname: lookup
# formatters.py(391):         obj_id = id(obj)
# formatters.py(392):         if obj_id in self.singleton_printers:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# formatters.py(395):         return self.lookup_by_type(_get_type(obj))
#  --- modulename: formatters, funcname: _get_type
# formatters.py(276):     return getattr(obj, '__class__', None) or type(obj)
#  --- modulename: formatters, funcname: lookup_by_type
# formatters.py(413):         if isinstance(typ, str):
# formatters.py(424):             for cls in pretty._get_mro(typ):
#  --- modulename: pretty, funcname: _get_mro
# pretty.py(317):     if not hasattr(obj_class, '__mro__'):
# pretty.py(328):         mro = obj_class.__mro__
# pretty.py(329):     return mro
# formatters.py(425):                 if cls in self.type_printers or self._in_deferred_types(cls):
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: formatters, funcname: _in_deferred_types
# formatters.py(556):         mod = getattr(cls, '__module__', None)
# formatters.py(557):         name = getattr(cls, '__name__', None)
# formatters.py(558):         key = (mod, name)
# formatters.py(559):         if key in self.deferred_printers:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# formatters.py(564):         return False
# formatters.py(424):             for cls in pretty._get_mro(typ):
# formatters.py(425):                 if cls in self.type_printers or self._in_deferred_types(cls):
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: formatters, funcname: _in_deferred_types
# formatters.py(556):         mod = getattr(cls, '__module__', None)
# formatters.py(557):         name = getattr(cls, '__name__', None)
# formatters.py(558):         key = (mod, name)
# formatters.py(559):         if key in self.deferred_printers:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# formatters.py(564):         return False
# formatters.py(424):             for cls in pretty._get_mro(typ):
# formatters.py(425):                 if cls in self.type_printers or self._in_deferred_types(cls):
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: formatters, funcname: _in_deferred_types
# formatters.py(556):         mod = getattr(cls, '__module__', None)
# formatters.py(557):         name = getattr(cls, '__name__', None)
# formatters.py(558):         key = (mod, name)
# formatters.py(559):         if key in self.deferred_printers:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# formatters.py(564):         return False
# formatters.py(424):             for cls in pretty._get_mro(typ):
# formatters.py(425):                 if cls in self.type_printers or self._in_deferred_types(cls):
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: formatters, funcname: _in_deferred_types
# formatters.py(556):         mod = getattr(cls, '__module__', None)
# formatters.py(557):         name = getattr(cls, '__name__', None)
# formatters.py(558):         key = (mod, name)
# formatters.py(559):         if key in self.deferred_printers:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# formatters.py(564):         return False
# formatters.py(424):             for cls in pretty._get_mro(typ):
# formatters.py(429):         raise KeyError("No registered printer for {0!r}".format(typ))
# formatters.py(962):             except KeyError:
# formatters.py(963):                 pass
# ...
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: session, funcname: <lambda>
# session.py(102): json_packer = lambda obj: jsonapi.dumps(obj, default=date_default,
# session.py(103):     ensure_ascii=False, allow_nan=False,
#  --- modulename: jsonapi, funcname: dumps
# jsonapi.py(37):     if 'separators' not in kwargs:
# jsonapi.py(38):         kwargs['separators'] = (',', ':')
# jsonapi.py(40):     s = jsonmod.dumps(o, **kwargs)
#  --- modulename: __init__, funcname: dumps
# __init__.py(227):     if (not skipkeys and ensure_ascii and
# __init__.py(232):     if cls is None:
# __init__.py(233):         cls = JSONEncoder
# __init__.py(234):     return cls(
# __init__.py(235):         skipkeys=skipkeys, ensure_ascii=ensure_ascii,
# __init__.py(236):         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
# __init__.py(237):         separators=separators, default=default, sort_keys=sort_keys,
# __init__.py(238):         **kw).encode(obj)
#  --- modulename: encoder, funcname: __init__
# encoder.py(147):         self.skipkeys = skipkeys
# encoder.py(148):         self.ensure_ascii = ensure_ascii
# encoder.py(149):         self.check_circular = check_circular
# encoder.py(150):         self.allow_nan = allow_nan
# encoder.py(151):         self.sort_keys = sort_keys
# encoder.py(152):         self.indent = indent
# encoder.py(153):         if separators is not None:
# encoder.py(154):             self.item_separator, self.key_separator = separators
# encoder.py(157):         if default is not None:
# encoder.py(158):             self.default = default
#  --- modulename: encoder, funcname: encode
# encoder.py(191):         if isinstance(o, str):
# encoder.py(199):         chunks = self.iterencode(o, _one_shot=True)
#  --- modulename: encoder, funcname: iterencode
# encoder.py(214):         if self.check_circular:
# encoder.py(215):             markers = {}
# encoder.py(218):         if self.ensure_ascii:
# encoder.py(221):             _encoder = encode_basestring
# encoder.py(223):         def floatstr(o, allow_nan=self.allow_nan,
# encoder.py(224):                 _repr=float.__repr__, _inf=INFINITY, _neginf=-INFINITY):
# encoder.py(246):         if (_one_shot and c_make_encoder is not None
# encoder.py(247):                 and self.indent is None):
# encoder.py(248):             _iterencode = c_make_encoder(
# encoder.py(249):                 markers, self.default, _encoder, self.indent,
# encoder.py(250):                 self.key_separator, self.item_separator, self.sort_keys,
# encoder.py(251):                 self.skipkeys, self.allow_nan)
# encoder.py(257):         return _iterencode(o, 0)
# encoder.py(200):         if not isinstance(chunks, (list, tuple)):
# encoder.py(202):         return ''.join(chunks)
# jsonapi.py(42):     if isinstance(s, unicode):
# jsonapi.py(43):         s = s.encode('utf8')
# jsonapi.py(45):     return s
# session.py(638):                         content,
# session.py(641):         to_send = []
# session.py(643):         if isinstance(ident, list):
# session.py(646):         elif ident is not None:
# session.py(647):             to_send.append(ident)
# session.py(648):         to_send.append(DELIM)
# session.py(650):         signature = self.sign(real_message)
#  --- modulename: session, funcname: sign
# session.py(591):         if self.auth is None:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# session.py(593):         h = self.auth.copy()
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
#  --- modulename: hmac, funcname: copy
# hmac.py(110):         other = self.__class__.__new__(self.__class__)
# hmac.py(111):         other.digest_cons = self.digest_cons
# hmac.py(112):         other.digest_size = self.digest_size
# hmac.py(113):         other.inner = self.inner.copy()
# hmac.py(114):         other.outer = self.outer.copy()
# hmac.py(115):         return other
# session.py(594):         for m in msg_list:
# session.py(595):             h.update(m)
#  --- modulename: hmac, funcname: update
# hmac.py(102):         self.inner.update(msg)
# session.py(594):         for m in msg_list:
# session.py(595):             h.update(m)
#  --- modulename: hmac, funcname: update
# hmac.py(102):         self.inner.update(msg)
# session.py(594):         for m in msg_list:
# session.py(595):             h.update(m)
#  --- modulename: hmac, funcname: update
# hmac.py(102):         self.inner.update(msg)
# session.py(594):         for m in msg_list:
# session.py(595):             h.update(m)
#  --- modulename: hmac, funcname: update
# hmac.py(102):         self.inner.update(msg)
# session.py(594):         for m in msg_list:
# session.py(596):         return str_to_bytes(h.hexdigest())
#  --- modulename: hmac, funcname: hexdigest
# hmac.py(139):         h = self._current()
#  --- modulename: hmac, funcname: _current
# hmac.py(122):         h = self.outer.copy()
# hmac.py(123):         h.update(self.inner.digest())
# hmac.py(124):         return h
# hmac.py(140):         return h.hexdigest()
#  --- modulename: py3compat, funcname: encode
# py3compat.py(20):     encoding = encoding or DEFAULT_ENCODING
# py3compat.py(21):     return u.encode(encoding, "replace")
# session.py(651):         to_send.append(signature)
# session.py(653):         to_send.extend(real_message)
# session.py(655):         return to_send
# session.py(738):         to_send.extend(buffers)
# session.py(739):         longest = max([ len(s) for s in to_send ])
#  --- modulename: session, funcname: <listcomp>
# session.py(739):         longest = max([ len(s) for s in to_send ])
# session.py(739):         longest = max([ len(s) for s in to_send ])
# session.py(739):         longest = max([ len(s) for s in to_send ])
# session.py(739):         longest = max([ len(s) for s in to_send ])
# session.py(739):         longest = max([ len(s) for s in to_send ])
# session.py(739):         longest = max([ len(s) for s in to_send ])
# session.py(739):         longest = max([ len(s) for s in to_send ])
# session.py(739):         longest = max([ len(s) for s in to_send ])
# session.py(740):         copy = (longest < self.copy_threshold)
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# session.py(742):         if buffers and track and not copy:
# session.py(747):             tracker = DONE
# session.py(748):             stream.send_multipart(to_send, copy=copy)
#  --- modulename: iostream, funcname: send_multipart
# iostream.py(262):         return self.io_thread.send_multipart(*args, **kwargs)
#  --- modulename: iostream, funcname: send_multipart
# iostream.py(212):         self.schedule(lambda : self._really_send(*args, **kwargs))
#  --- modulename: iostream, funcname: schedule
# iostream.py(200):         if self.thread.is_alive():
#  --- modulename: threading, funcname: is_alive
# threading.py(1088):         assert self._initialized, "Thread.__init__() not called"
# threading.py(1089):         if self._is_stopped or not self._started.is_set():
#  --- modulename: threading, funcname: is_set
# threading.py(509):         return self._flag
# threading.py(1091):         self._wait_for_tstate_lock(False)
#  --- modulename: threading, funcname: _wait_for_tstate_lock
# threading.py(1045):         lock = self._tstate_lock
# threading.py(1046):         if lock is None:  # already determined that the C code is done
# threading.py(1048):         elif lock.acquire(block, timeout):
# threading.py(1092):         return not self._is_stopped
# iostream.py(201):             self._events.append(f)
# iostream.py(203):             self._event_pipe.send(b'')
#  --- modulename: iostream, funcname: _event_pipe
# iostream.py(96):         try:
# iostream.py(97):             event_pipe = self._local.event_pipe
# iostream.py(105):         return event_pipe
#  --- modulename: socket, funcname: send
# socket.py(382):         if routing_id is not None:
# socket.py(387):         if group is not None:
# socket.py(392):         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
# session.py(750):         if self.debug:
#  --- modulename: traitlets, funcname: __get__
# traitlets.py(553):         if obj is None:
# traitlets.py(556):             return self.get(obj, cls)
#  --- modulename: traitlets, funcname: get
# traitlets.py(527):         try:
# traitlets.py(528):             value = obj._trait_values[self.name]
# traitlets.py(543):             return value
# session.py(755):         msg['tracker'] = tracker
# session.py(757):         return msg
# display.py(300):     for obj in objs:
# display.py(312):     if display_id:
# display.py(313):         return DisplayHandle(display_id)
#  --- modulename: display, funcname: __init__
# display.py(353):         if display_id is None:
# display.py(355):         self.display_id = display_id
# fastprogress.py(160):         if self.parent is not None: self.parent.on_interrupt()
#  --- modulename: fastprogress, funcname: on_interrupt
# fastprogress.py(188):         if self.clean_on_interrupt: self.out.update(HTML(''))
# fastprogress.py(161):         self.on_iter_end()
#  --- modulename: fastprogress, funcname: on_iter_end
# fastprogress.py(164):         if not self.leave and self.display: clear_output()#self.out.update(HTML(''))
# fastprogress.py(165):         self.is_active=False
# fastprogress.py(71):             raise
#  --- modulename: fastprogress, funcname: __iter__
#  --- modulename: fastprogress, funcname: __iter__
# fastprogress.py(69):         except:
# fastprogress.py(70):             self.on_interrupt()
#  --- modulename: fastprogress, funcname: on_interrupt
# fastprogress.py(159):         self.on_update(0, 'Interrupted', interrupted=True)
#  --- modulename: fastprogress, funcname: on_update
# fastprogress.py(168):         self.progress = html_progress_bar(val, self.total, text, interrupted)
#  --- modulename: fastprogress, funcname: html_progress_bar
# fastprogress.py(116):     bar_style = 'progress-bar-interrupted' if interrupted else ''
# fastprogress.py(134):     """
# fastprogress.py(169):         if self.display: self.out.update(HTML(self.progress))
# fastprogress.py(170):         elif self.parent is not None: self.parent.show()
# fastprogress.py(160):         if self.parent is not None: self.parent.on_interrupt()
# fastprogress.py(161):         self.on_iter_end()
#  --- modulename: fastprogress, funcname: on_iter_end
# fastprogress.py(164):         if not self.leave and self.display: clear_output()#self.out.update(HTML(''))
# fastprogress.py(165):         self.is_active=False
# fastprogress.py(71):             raise
# basic_train.py(108):     except Exception as e:
# basic_train.py(111):     finally: cb_handler.on_train_end(exception)
#  --- modulename: callback, funcname: on_train_end
# callback.py(322):         self('train_end', exception=exception)
#  --- modulename: callback, funcname: __call__
# callback.py(248):         if call_mets:
# callback.py(249):             for met in self.metrics: self._call_and_update(met, cb_name, **kwargs)
#  --- modulename: callback, funcname: _call_and_update
# callback.py(240):         new = ifnone(getattr(cb, f'on_{cb_name}')(**self.state_dict, **kwargs), dict())
#  --- modulename: callback, funcname: on_train_end
# callback.py(190):         pass
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# callback.py(241):         for k,v in new.items():
# callback.py(249):             for met in self.metrics: self._call_and_update(met, cb_name, **kwargs)
# callback.py(250):         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
#  --- modulename: callback, funcname: _call_and_update
# callback.py(240):         new = ifnone(getattr(cb, f'on_{cb_name}')(**self.state_dict, **kwargs), dict())
#  --- modulename: callback, funcname: on_train_end
# callback.py(190):         pass
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# callback.py(241):         for k,v in new.items():
# callback.py(250):         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-acc90573c8ab> in <module>
#       1 import trace
#       2 tracer = trace.Trace(count=True, trace=True)
# ----> 3 tracer.runfunc(learn.fit, 1)
#
# /data/anaconda3/envs/fastaidev/lib/python3.7/trace.py in runfunc(self, func, *args, **kw)
#     458             sys.settrace(self.globaltrace)
#     459         try:
# --> 460             result = func(*args, **kw)
#     461         finally:
#     462             if not self.donothing:
#
# /data/git/fastai/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     194         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     195         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
# --> 196         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     197
#     198     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /data/git/fastai/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      96             cb_handler.set_dl(learn.data.train_dl)
#      97             cb_handler.on_epoch_begin()
# ---> 98             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#      99                 xb, yb = cb_handler.on_batch_begin(xb, yb)
#     100                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#
# /data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      64         self.update(0)
#      65         try:
# ---> 66             for i,o in enumerate(self._gen):
#      67                 yield o
#      68                 if self.auto_update: self.update(i+1)
#
# /data/git/fastai/fastai/basic_data.py in __iter__(self)
#      73     def __iter__(self):
#      74         "Process and returns items from `DataLoader`."
# ---> 75         for b in self.dl: yield self.proc_batch(b)
#      76
#      77     @classmethod
#
# /data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     629         while True:
#     630             assert (not self.shutdown and self.batches_outstanding > 0)
# --> 631             idx, batch = self._get_batch()
#     632             self.batches_outstanding -= 1
#     633             if idx != self.rcvd_idx:
#
# /data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _get_batch(self)
#     599             while self.pin_memory_thread.is_alive():
#     600                 try:
# --> 601                     return self.data_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)
#     602                 except queue.Empty:
#     603                     continue
#
# /data/anaconda3/envs/fastaidev/lib/python3.7/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# /data/anaconda3/envs/fastaidev/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
img = learn.data.train_ds[0][0]
# learn.predict(img)

tracer.runfunc(learn.predict, img)
# Out:
#  --- modulename: basic_train, funcname: predict
# basic_train.py(360):         batch = self.data.one_item(item)
#  --- modulename: basic_data, funcname: one_item
# basic_data.py(179):         ds = self.single_ds
#  --- modulename: basic_data, funcname: single_ds
# basic_data.py(211):     def single_ds(self)->Dataset: return self._grab_dataset(self.single_dl)
#  --- modulename: basic_data, funcname: _grab_dataset
# basic_data.py(202):         ds = dl.dl.dataset
# basic_data.py(203):         while hasattr(ds, 'dataset'): ds = ds.dataset
#  --- modulename: data_block, funcname: __getattr__
# data_block.py(621):         x = super().__getattribute__('x')
# data_block.py(622):         res = getattr(x, k, None)
# data_block.py(623):         if res is not None and k not in ['classes', 'c']: return res
# data_block.py(624):         y = super().__getattribute__('y')
# data_block.py(625):         res = getattr(y, k, None)
# data_block.py(626):         if res is not None: return res
# data_block.py(627):         raise AttributeError(k)
# basic_data.py(204):         return ds
# basic_data.py(180):         with ds.set_item(item):
#  --- modulename: contextlib, funcname: helper
# contextlib.py(239):         return _GeneratorContextManager(func, args, kwds)
#  --- modulename: contextlib, funcname: __init__
# contextlib.py(82):         self.gen = func(*args, **kwds)
# contextlib.py(83):         self.func, self.args, self.kwds = func, args, kwds
# contextlib.py(85):         doc = getattr(func, "__doc__", None)
# contextlib.py(86):         if doc is None:
# contextlib.py(88):         self.__doc__ = doc
#  --- modulename: contextlib, funcname: __enter__
# contextlib.py(110):         del self.args, self.kwds, self.func
# contextlib.py(111):         try:
# contextlib.py(112):             return next(self.gen)
#  --- modulename: data_block, funcname: set_item
# data_block.py(596):         self.item = self.x.process_one(item)
#  --- modulename: data_block, funcname: process_one
# data_block.py(80):         if processor is not None: self.processor = processor
# data_block.py(81):         self.processor = listify(self.processor)
#  --- modulename: core, funcname: listify
# core.py(104):     if p is None: p=[]
# core.py(105):     elif isinstance(p, str):          p = [p]
# core.py(106):     elif not isinstance(p, Iterable): p = [p]
#  --- modulename: abc, funcname: __instancecheck__
# abc.py(139):             return _abc_instancecheck(cls, instance)
# core.py(109):         try: a = len(p)
# core.py(111):     n = q if type(q)==int else len(p) if q is None else len(q)
# core.py(112):     if len(p)==1: p = p * n
# core.py(113):     assert len(p)==n, f'List len mismatch ({len(p)} vs {n})'
# core.py(114):     return list(p)
# data_block.py(82):         for p in self.processor: item = p.process_one(item)
# data_block.py(83):         return item
# data_block.py(597):         yield None
# basic_data.py(181):             return self.one_batch(ds_type=DatasetType.Single, detach=detach, denorm=denorm, cpu=cpu)
#  --- modulename: basic_data, funcname: one_batch
# basic_data.py(165):         dl = self.dl(ds_type)
#  --- modulename: basic_data, funcname: dl
# basic_data.py(128):         return (self.train_dl if ds_type == DatasetType.Train else
# basic_data.py(129):                 self.test_dl if ds_type == DatasetType.Test else
# basic_data.py(130):                 self.valid_dl if ds_type == DatasetType.Valid else
# basic_data.py(131):                 self.single_dl if ds_type == DatasetType.Single else
# basic_data.py(166):         w = self.num_workers
#  --- modulename: basic_data, funcname: __getattr__
# basic_data.py(122):     def __getattr__(self,k:int)->Any: return getattr(self.train_dl, k)
#  --- modulename: basic_data, funcname: num_workers
# basic_data.py(50):     def num_workers(self):   return self.dl.num_workers
# basic_data.py(167):         self.num_workers = 0
# basic_data.py(168):         try:     x,y = next(iter(dl))
#  --- modulename: basic_data, funcname: __iter__
# basic_data.py(75):         for b in self.dl: yield self.proc_batch(b)
#  --- modulename: dataloader, funcname: __iter__
# dataloader.py(819):         return _DataLoaderIter(self)
#  --- modulename: dataloader, funcname: __init__
# dataloader.py(519):         self.dataset = loader.dataset
# dataloader.py(520):         self.collate_fn = loader.collate_fn
# dataloader.py(521):         self.batch_sampler = loader.batch_sampler
# dataloader.py(522):         self.num_workers = loader.num_workers
# dataloader.py(523):         self.pin_memory = loader.pin_memory and torch.cuda.is_available()
#  --- modulename: __init__, funcname: is_available
# __init__.py(47):     if (not hasattr(torch._C, '_cuda_isDriverSufficient') or
# __init__.py(48):             not torch._C._cuda_isDriverSufficient()):
# __init__.py(50):     return torch._C._cuda_getDeviceCount() > 0
# dataloader.py(524):         self.timeout = loader.timeout
# dataloader.py(526):         self.sample_iter = iter(self.batch_sampler)
# dataloader.py(528):         base_seed = torch.LongTensor(1).random_().item()
# dataloader.py(530):         if self.num_workers > 0:
#  --- modulename: dataloader, funcname: __next__
# dataloader.py(613):         if self.num_workers == 0:  # same-process loading
# dataloader.py(614):             indices = next(self.sample_iter)  # may raise StopIteration
#  --- modulename: sampler, funcname: __iter__
# sampler.py(159):         batch = []
# sampler.py(160):         for idx in self.sampler:
#  --- modulename: sampler, funcname: __iter__
# sampler.py(34):         return iter(range(len(self.data_source)))
#  --- modulename: data_block, funcname: __len__
# data_block.py(591):     def __len__(self)->int: return len(self.x) if self.item is None else 1
# sampler.py(161):             batch.append(idx)
# sampler.py(162):             if len(batch) == self.batch_size:
# sampler.py(163):                 yield batch
# dataloader.py(615):             batch = self.collate_fn([self.dataset[i] for i in indices])
#  --- modulename: dataloader, funcname: <listcomp>
# dataloader.py(615):             batch = self.collate_fn([self.dataset[i] for i in indices])
#  --- modulename: data_block, funcname: __getitem__
# data_block.py(632):         idxs = try_int(idxs)
#  --- modulename: torch_core, funcname: try_int
# torch_core.py(367):     if isinstance(o, (np.ndarray,Tensor)): return o if o.ndim else int(o)
# torch_core.py(368):     if isinstance(o, collections.Sized) or getattr(o,'__array_interface__',False): return o
#  --- modulename: abc, funcname: __instancecheck__
# abc.py(139):             return _abc_instancecheck(cls, instance)
# torch_core.py(369):     try: return int(o)
# data_block.py(633):         if isinstance(idxs, Integral):
#  --- modulename: abc, funcname: __instancecheck__
# abc.py(139):             return _abc_instancecheck(cls, instance)
#  --- modulename: abc, funcname: __subclasscheck__
# abc.py(143):             return _abc_subclasscheck(cls, subclass)
# data_block.py(634):             if self.item is None: x,y = self.x[idxs],self.y[idxs]
# data_block.py(635):             else:                 x,y = self.item   ,0
# data_block.py(636):             if self.tfms or self.tfmargs:
# data_block.py(637):                 x = x.apply_tfms(self.tfms, **self.tfmargs)
#  --- modulename: image, funcname: apply_tfms
# image.py(100):         if not (tfms or xtra or size): return self
# data_block.py(638):             if hasattr(self, 'tfms_y') and self.tfm_y and self.item is None:
# data_block.py(640):             if y is None: y=0
# data_block.py(641):             return x,y
# dataloader.py(615):             batch = self.collate_fn([self.dataset[i] for i in indices])
#  --- modulename: torch_core, funcname: data_collate
# torch_core.py(126):     return torch.utils.data.dataloader.default_collate(to_data(batch))
#  --- modulename: torch_core, funcname: to_data
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
#  --- modulename: torch_core, funcname: <listcomp>
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: torch_core, funcname: to_data
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
#  --- modulename: torch_core, funcname: <listcomp>
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: torch_core, funcname: to_data
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
# torch_core.py(100):     return b.data if isinstance(b,ItemBase) else b
#  --- modulename: image, funcname: data
# image.py(214):         return self.px
#  --- modulename: image, funcname: px
# image.py(145):         self.refresh()
#  --- modulename: image, funcname: refresh
# image.py(128):         if self._logit_px is not None:
# image.py(131):         if self._affine_mat is not None or self._flow is not None:
# image.py(135):         return self
# image.py(146):         return self._px
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: torch_core, funcname: to_data
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
# torch_core.py(100):     return b.data if isinstance(b,ItemBase) else b
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: dataloader, funcname: default_collate
# dataloader.py(199):     error_msg = "batch must contain tensors, numbers, dicts or lists; found {}"
# dataloader.py(200):     elem_type = type(batch[0])
# dataloader.py(201):     if isinstance(batch[0], torch.Tensor):
# dataloader.py(210):     elif elem_type.__module__ == 'numpy' and elem_type.__name__ != 'str_' \
# dataloader.py(222):     elif isinstance(batch[0], int_classes):
# dataloader.py(224):     elif isinstance(batch[0], float):
# dataloader.py(226):     elif isinstance(batch[0], string_classes):
# dataloader.py(228):     elif isinstance(batch[0], container_abcs.Mapping):
#  --- modulename: abc, funcname: __instancecheck__
# abc.py(139):             return _abc_instancecheck(cls, instance)
# dataloader.py(230):     elif isinstance(batch[0], container_abcs.Sequence):
#  --- modulename: abc, funcname: __instancecheck__
# abc.py(139):             return _abc_instancecheck(cls, instance)
# dataloader.py(231):         transposed = zip(*batch)
# dataloader.py(232):         return [default_collate(samples) for samples in transposed]
#  --- modulename: dataloader, funcname: <listcomp>
# dataloader.py(232):         return [default_collate(samples) for samples in transposed]
#  --- modulename: dataloader, funcname: default_collate
# dataloader.py(199):     error_msg = "batch must contain tensors, numbers, dicts or lists; found {}"
# dataloader.py(200):     elem_type = type(batch[0])
# dataloader.py(201):     if isinstance(batch[0], torch.Tensor):
# dataloader.py(202):         out = None
# dataloader.py(203):         if _use_shared_memory:
# dataloader.py(209):         return torch.stack(batch, 0, out=out)
# dataloader.py(232):         return [default_collate(samples) for samples in transposed]
#  --- modulename: dataloader, funcname: default_collate
# dataloader.py(199):     error_msg = "batch must contain tensors, numbers, dicts or lists; found {}"
# dataloader.py(200):     elem_type = type(batch[0])
# dataloader.py(201):     if isinstance(batch[0], torch.Tensor):
# dataloader.py(210):     elif elem_type.__module__ == 'numpy' and elem_type.__name__ != 'str_' \
# dataloader.py(222):     elif isinstance(batch[0], int_classes):
# dataloader.py(223):         return torch.LongTensor(batch)
# dataloader.py(232):         return [default_collate(samples) for samples in transposed]
# dataloader.py(616):             if self.pin_memory:
# dataloader.py(617):                 batch = pin_memory_batch(batch)
#  --- modulename: dataloader, funcname: pin_memory_batch
# dataloader.py(238):     if isinstance(batch, torch.Tensor):
# dataloader.py(240):     elif isinstance(batch, string_classes):
# dataloader.py(242):     elif isinstance(batch, container_abcs.Mapping):
#  --- modulename: abc, funcname: __instancecheck__
# abc.py(139):             return _abc_instancecheck(cls, instance)
# dataloader.py(244):     elif isinstance(batch, container_abcs.Sequence):
#  --- modulename: abc, funcname: __instancecheck__
# abc.py(139):             return _abc_instancecheck(cls, instance)
# dataloader.py(245):         return [pin_memory_batch(sample) for sample in batch]
#  --- modulename: dataloader, funcname: <listcomp>
# dataloader.py(245):         return [pin_memory_batch(sample) for sample in batch]
#  --- modulename: dataloader, funcname: pin_memory_batch
# dataloader.py(238):     if isinstance(batch, torch.Tensor):
# dataloader.py(239):         return batch.pin_memory()
# dataloader.py(245):         return [pin_memory_batch(sample) for sample in batch]
#  --- modulename: dataloader, funcname: pin_memory_batch
# dataloader.py(238):     if isinstance(batch, torch.Tensor):
# dataloader.py(239):         return batch.pin_memory()
# dataloader.py(245):         return [pin_memory_batch(sample) for sample in batch]
# dataloader.py(618):             return batch
#  --- modulename: basic_data, funcname: proc_batch
# basic_data.py(69):         b = to_device(b, self.device)
#  --- modulename: torch_core, funcname: to_device
# torch_core.py(119):     device = ifnone(device, defaults.device)
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# torch_core.py(120):     if is_listy(b): return [to_device(o, device) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
#  --- modulename: torch_core, funcname: <listcomp>
# torch_core.py(120):     if is_listy(b): return [to_device(o, device) for o in b]
#  --- modulename: torch_core, funcname: to_device
# torch_core.py(119):     device = ifnone(device, defaults.device)
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# torch_core.py(120):     if is_listy(b): return [to_device(o, device) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
# torch_core.py(121):     if is_dict(b): return {k: to_device(v, device) for k, v in b.items()}
#  --- modulename: core, funcname: is_dict
# core.py(53): def is_dict(x:Any)->bool: return isinstance(x, dict)
# torch_core.py(122):     return b.to(device, non_blocking=True)
# torch_core.py(120):     if is_listy(b): return [to_device(o, device) for o in b]
#  --- modulename: torch_core, funcname: to_device
# torch_core.py(119):     device = ifnone(device, defaults.device)
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# torch_core.py(120):     if is_listy(b): return [to_device(o, device) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
# torch_core.py(121):     if is_dict(b): return {k: to_device(v, device) for k, v in b.items()}
#  --- modulename: core, funcname: is_dict
# core.py(53): def is_dict(x:Any)->bool: return isinstance(x, dict)
# torch_core.py(122):     return b.to(device, non_blocking=True)
# torch_core.py(120):     if is_listy(b): return [to_device(o, device) for o in b]
# basic_data.py(70):         for f in listify(self.tfms): b = f(b)
#  --- modulename: core, funcname: listify
# core.py(104):     if p is None: p=[]
# core.py(105):     elif isinstance(p, str):          p = [p]
# core.py(106):     elif not isinstance(p, Iterable): p = [p]
#  --- modulename: abc, funcname: __instancecheck__
# abc.py(139):             return _abc_instancecheck(cls, instance)
# core.py(109):         try: a = len(p)
# core.py(111):     n = q if type(q)==int else len(p) if q is None else len(q)
# core.py(112):     if len(p)==1: p = p * n
# core.py(113):     assert len(p)==n, f'List len mismatch ({len(p)} vs {n})'
# core.py(114):     return list(p)
# basic_data.py(71):         return b
#  --- modulename: basic_data, funcname: __iter__
#  --- modulename: dataloader, funcname: __del__
# dataloader.py(716):         if self.num_workers > 0:
#  --- modulename: sampler, funcname: __iter__
# basic_data.py(169):         finally: self.num_workers = w
# basic_data.py(170):         if detach: x,y = to_detach(x,cpu=cpu),to_detach(y,cpu=cpu)
# basic_data.py(171):         norm = getattr(self,'norm',False)
#  --- modulename: basic_data, funcname: __getattr__
# basic_data.py(122):     def __getattr__(self,k:int)->Any: return getattr(self.train_dl, k)
#  --- modulename: basic_data, funcname: __getattr__
# basic_data.py(38):     def __getattr__(self,k:str)->Any: return getattr(self.dl, k)
#  --- modulename: basic_data, funcname: DataLoader___getattr__
# basic_data.py(20): def DataLoader___getattr__(dl, k:str)->Any: return getattr(dl.dataset, k)
#  --- modulename: data_block, funcname: __getattr__
# data_block.py(621):         x = super().__getattribute__('x')
# data_block.py(622):         res = getattr(x, k, None)
# data_block.py(623):         if res is not None and k not in ['classes', 'c']: return res
# data_block.py(624):         y = super().__getattribute__('y')
# data_block.py(625):         res = getattr(y, k, None)
# data_block.py(626):         if res is not None: return res
# data_block.py(627):         raise AttributeError(k)
# basic_data.py(172):         if denorm and norm:
# basic_data.py(175):         return x,y
#  --- modulename: contextlib, funcname: __exit__
# contextlib.py(117):         if type is None:
# contextlib.py(118):             try:
# contextlib.py(119):                 next(self.gen)
#  --- modulename: data_block, funcname: set_item
# data_block.py(598):         self.item = None
# contextlib.py(120):             except StopIteration:
# contextlib.py(121):                 return False
# basic_train.py(361):         res = self.pred_batch(batch=batch)
#  --- modulename: basic_train, funcname: pred_batch
# basic_train.py(337):         if batch is not None: xb,yb = batch
# basic_train.py(339):         cb_handler = CallbackHandler(self.callbacks)
#  --- modulename: callback, funcname: __post_init__
# callback.py(231):         self.callbacks = ifnone(self.callbacks, [])
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# callback.py(232):         self.metrics = ifnone(self.metrics, [])
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# callback.py(233):         self.metrics = [(met if isinstance(met, Callback) else AverageMetric(met)) for met in self.metrics]
#  --- modulename: callback, funcname: <listcomp>
# callback.py(233):         self.metrics = [(met if isinstance(met, Callback) else AverageMetric(met)) for met in self.metrics]
# callback.py(234):         self.callbacks = sorted(self.callbacks, key=lambda o: getattr(o, '_order', 0))
# callback.py(235):         self.smoothener = SmoothenValue(self.beta)
#  --- modulename: callback, funcname: __init__
# callback.py(210):         self.beta,self.n,self.mov_avg = beta,0,0
# callback.py(236):         self.state_dict:Dict[str,Union[int,float,Tensor]]=_get_init_state()
#  --- modulename: callback, funcname: _get_init_state
# callback.py(220): def _get_init_state(): return {'epoch':0, 'iteration':0, 'num_batch':0}
# basic_train.py(340):         xb,yb = cb_handler.on_batch_begin(xb,yb, train=False)
#  --- modulename: callback, funcname: on_batch_begin
# callback.py(276):         self.state_dict.update(dict(last_input=xb, last_target=yb, train=train,
# callback.py(277):             stop_epoch=False, skip_step=False, skip_zero=False, skip_bwd=False))
# callback.py(278):         self('batch_begin', mets = not self.state_dict['train'])
#  --- modulename: callback, funcname: __call__
# callback.py(248):         if call_mets:
# callback.py(249):             for met in self.metrics: self._call_and_update(met, cb_name, **kwargs)
# callback.py(250):         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
# callback.py(279):         return self.state_dict['last_input'], self.state_dict['last_target']
# basic_train.py(341):         preds = loss_batch(self.model.eval(), xb, yb, cb_handler=cb_handler)
#  --- modulename: module, funcname: eval
# module.py(954):         return self.train(False)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# module.py(521):         def remove_from(*dicts):
# module.py(526):         params = self.__dict__.get('_parameters')
# module.py(527):         if isinstance(value, Parameter):
# module.py(533):         elif params is not None and name in params:
# module.py(540):             modules = self.__dict__.get('_modules')
# module.py(541):             if isinstance(value, Module):
# module.py(547):             elif modules is not None and name in modules:
# module.py(554):                 buffers = self.__dict__.get('_buffers')
# module.py(555):                 if buffers is not None and name in buffers:
# module.py(562):                     object.__setattr__(self, name, value)
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(859):         memo = set()
# module.py(860):         for name, module in self._modules.items():
# module.py(944):         return self
# module.py(942):         for module in self.children():
#  --- modulename: module, funcname: children
# module.py(842):         for name, module in self.named_children():
#  --- modulename: module, funcname: named_children
# module.py(860):         for name, module in self._modules.items():
# module.py(861):             if module is not None and module not in memo:
# module.py(862):                 memo.add(module)
# module.py(863):                 yield name, module
# module.py(843):             yield module
# module.py(943):             module.train(mode)
#  --- modulename: module, funcname: train
# module.py(941):         self.training = mode
#  --- modulename: module, funcname: __setattr__
# ...
# module.py(478):         for hook in self._forward_hooks.values():
# module.py(484):         if len(self._backward_hooks) > 0:
# module.py(497):         return result
# container.py(91):         for module in self._modules.values():
# container.py(92):             input = module(input)
#  --- modulename: module, funcname: __call__
# module.py(472):         for hook in self._forward_pre_hooks.values():
# module.py(474):         if torch._C._get_tracing_state():
# module.py(477):             result = self.forward(*input, **kwargs)
#  --- modulename: activation, funcname: forward
# activation.py(46):         return F.threshold(input, self.threshold, self.value, self.inplace)
#  --- modulename: functional, funcname: threshold
# functional.py(698):     if inplace:
# functional.py(699):         return torch._C._nn.threshold_(input, threshold, value)
# module.py(478):         for hook in self._forward_hooks.values():
# module.py(484):         if len(self._backward_hooks) > 0:
# module.py(497):         return result
# container.py(91):         for module in self._modules.values():
# container.py(92):             input = module(input)
#  --- modulename: module, funcname: __call__
# module.py(472):         for hook in self._forward_pre_hooks.values():
# module.py(474):         if torch._C._get_tracing_state():
# module.py(477):             result = self.forward(*input, **kwargs)
#  --- modulename: batchnorm, funcname: forward
# batchnorm.py(53):         self._check_input_dim(input)
#  --- modulename: batchnorm, funcname: _check_input_dim
# batchnorm.py(156):         if input.dim() != 2 and input.dim() != 3:
# batchnorm.py(55):         exponential_average_factor = 0.0
# batchnorm.py(57):         if self.training and self.track_running_stats:
# batchnorm.py(64):         return F.batch_norm(
# batchnorm.py(65):             input, self.running_mean, self.running_var, self.weight, self.bias,
#  --- modulename: module, funcname: __getattr__
# module.py(505):         if '_parameters' in self.__dict__:
# module.py(506):             _parameters = self.__dict__['_parameters']
# module.py(507):             if name in _parameters:
# module.py(509):         if '_buffers' in self.__dict__:
# module.py(510):             _buffers = self.__dict__['_buffers']
# module.py(511):             if name in _buffers:
# module.py(512):                 return _buffers[name]
#  --- modulename: module, funcname: __getattr__
# module.py(505):         if '_parameters' in self.__dict__:
# module.py(506):             _parameters = self.__dict__['_parameters']
# module.py(507):             if name in _parameters:
# module.py(509):         if '_buffers' in self.__dict__:
# module.py(510):             _buffers = self.__dict__['_buffers']
# module.py(511):             if name in _buffers:
# module.py(512):                 return _buffers[name]
#  --- modulename: module, funcname: __getattr__
# module.py(505):         if '_parameters' in self.__dict__:
# module.py(506):             _parameters = self.__dict__['_parameters']
# module.py(507):             if name in _parameters:
# module.py(508):                 return _parameters[name]
#  --- modulename: module, funcname: __getattr__
# module.py(505):         if '_parameters' in self.__dict__:
# module.py(506):             _parameters = self.__dict__['_parameters']
# module.py(507):             if name in _parameters:
# module.py(508):                 return _parameters[name]
# batchnorm.py(66):             self.training or not self.track_running_stats,
# batchnorm.py(67):             exponential_average_factor, self.eps)
#  --- modulename: functional, funcname: batch_norm
# functional.py(1363):     if training:
# functional.py(1367):     return torch.batch_norm(
# functional.py(1368):         input, weight, bias, running_mean, running_var,
# functional.py(1369):         training, momentum, eps, torch.backends.cudnn.enabled
#  --- modulename: __init__, funcname: __get__
# __init__.py(448):         return self.getter()
# module.py(478):         for hook in self._forward_hooks.values():
# module.py(484):         if len(self._backward_hooks) > 0:
# module.py(497):         return result
# container.py(91):         for module in self._modules.values():
# container.py(92):             input = module(input)
#  --- modulename: module, funcname: __call__
# module.py(472):         for hook in self._forward_pre_hooks.values():
# module.py(474):         if torch._C._get_tracing_state():
# module.py(477):             result = self.forward(*input, **kwargs)
#  --- modulename: dropout, funcname: forward
# dropout.py(54):         return F.dropout(input, self.p, self.training, self.inplace)
#  --- modulename: functional, funcname: dropout
# functional.py(620):     if p < 0 or p > 1:
# functional.py(623):     f = _VF.dropout_ if inplace else _VF.dropout
# functional.py(624):     return f(input, p, training)
# module.py(478):         for hook in self._forward_hooks.values():
# module.py(484):         if len(self._backward_hooks) > 0:
# module.py(497):         return result
# container.py(91):         for module in self._modules.values():
# container.py(92):             input = module(input)
#  --- modulename: module, funcname: __call__
# module.py(472):         for hook in self._forward_pre_hooks.values():
# module.py(474):         if torch._C._get_tracing_state():
# module.py(477):             result = self.forward(*input, **kwargs)
#  --- modulename: linear, funcname: forward
# linear.py(63):         return F.linear(input, self.weight, self.bias)
#  --- modulename: module, funcname: __getattr__
# module.py(505):         if '_parameters' in self.__dict__:
# module.py(506):             _parameters = self.__dict__['_parameters']
# module.py(507):             if name in _parameters:
# module.py(508):                 return _parameters[name]
#  --- modulename: module, funcname: __getattr__
# module.py(505):         if '_parameters' in self.__dict__:
# module.py(506):             _parameters = self.__dict__['_parameters']
# module.py(507):             if name in _parameters:
# module.py(508):                 return _parameters[name]
#  --- modulename: functional, funcname: linear
# functional.py(1136):     if input.dim() == 2 and bias is not None:
# functional.py(1138):         return torch.addmm(bias, input, weight.t())
# module.py(478):         for hook in self._forward_hooks.values():
# module.py(484):         if len(self._backward_hooks) > 0:
# module.py(497):         return result
# container.py(91):         for module in self._modules.values():
# container.py(93):         return input
# module.py(478):         for hook in self._forward_hooks.values():
# module.py(484):         if len(self._backward_hooks) > 0:
# module.py(497):         return result
# container.py(91):         for module in self._modules.values():
# container.py(93):         return input
# module.py(478):         for hook in self._forward_hooks.values():
# module.py(484):         if len(self._backward_hooks) > 0:
# module.py(497):         return result
# basic_train.py(26):     out = cb_handler.on_loss_begin(out)
#  --- modulename: callback, funcname: on_loss_begin
# callback.py(283):         self.state_dict['last_output'] = out
# callback.py(284):         self('loss_begin', call_mets=False)
#  --- modulename: callback, funcname: __call__
# callback.py(248):         if call_mets:
# callback.py(250):         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
# callback.py(285):         return self.state_dict['last_output']
# basic_train.py(28):     if not loss_func: return to_detach(out), yb[0].detach()
#  --- modulename: torch_core, funcname: to_detach
# torch_core.py(92):     if is_listy(b): return [to_detach(o, cpu) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
# torch_core.py(93):     if not isinstance(b,Tensor): return b
# torch_core.py(94):     b = b.detach()
# torch_core.py(95):     return b.cpu() if cpu else b
# basic_train.py(342):         res = _loss_func2activ(self.loss_func)(preds[0])
#  --- modulename: basic_train, funcname: _loss_func2activ
# basic_train.py(124):     if getattr(loss_func,'keywords',None):
# basic_train.py(126):     axis = getattr(loss_func, 'axis', -1)
# basic_train.py(128):     loss_func = getattr(loss_func, 'func', loss_func)
# basic_train.py(130):     loss_func = getattr(loss_func, 'func', loss_func)
#  --- modulename: module, funcname: __getattr__
# module.py(505):         if '_parameters' in self.__dict__:
# module.py(506):             _parameters = self.__dict__['_parameters']
# module.py(507):             if name in _parameters:
# module.py(509):         if '_buffers' in self.__dict__:
# module.py(510):             _buffers = self.__dict__['_buffers']
# module.py(511):             if name in _buffers:
# module.py(513):         if '_modules' in self.__dict__:
# module.py(514):             modules = self.__dict__['_modules']
# module.py(515):             if name in modules:
# module.py(517):         raise AttributeError("'{}' object has no attribute '{}'".format(
# module.py(518):             type(self).__name__, name))
# basic_train.py(131):     cls_name = camel2snake(loss_func.__class__.__name__)
#  --- modulename: core, funcname: camel2snake
# core.py(120):     s1 = re.sub(_camel_re1, r'\1_\2', name)
#  --- modulename: re, funcname: sub
# re.py(192):     return _compile(pattern, flags).sub(repl, string, count)
#  --- modulename: re, funcname: _compile
# re.py(273):     if isinstance(flags, RegexFlag):
# re.py(275):     try:
# re.py(276):         return _cache[type(pattern), pattern, flags]
# re.py(277):     except KeyError:
# re.py(278):         pass
# re.py(279):     if isinstance(pattern, Pattern):
# re.py(280):         if flags:
# re.py(283):         return pattern
#  --- modulename: re, funcname: _subx
# re.py(309):     template = _compile_repl(template, pattern)
# re.py(310):     if not template[0] and len(template[1]) == 1:
# re.py(313):     def filter(match, template=template):
# re.py(315):     return filter
#  --- modulename: re, funcname: filter
# re.py(314):         return sre_parse.expand_template(template, match)
#  --- modulename: sre_parse, funcname: expand_template
# sre_parse.py(1037):     g = match.group
# sre_parse.py(1038):     empty = match.string[:0]
# sre_parse.py(1039):     groups, literals = template
# sre_parse.py(1040):     literals = literals[:]
# sre_parse.py(1041):     try:
# sre_parse.py(1042):         for index, group in groups:
# sre_parse.py(1043):             literals[index] = g(group) or empty
# sre_parse.py(1042):         for index, group in groups:
# sre_parse.py(1043):             literals[index] = g(group) or empty
# sre_parse.py(1042):         for index, group in groups:
# sre_parse.py(1046):     return empty.join(literals)
# core.py(121):     return re.sub(_camel_re2, r'\1_\2', s1).lower()
#  --- modulename: re, funcname: sub
# re.py(192):     return _compile(pattern, flags).sub(repl, string, count)
#  --- modulename: re, funcname: _compile
# re.py(273):     if isinstance(flags, RegexFlag):
# re.py(275):     try:
# re.py(276):         return _cache[type(pattern), pattern, flags]
# re.py(277):     except KeyError:
# re.py(278):         pass
# re.py(279):     if isinstance(pattern, Pattern):
# re.py(280):         if flags:
# re.py(283):         return pattern
#  --- modulename: re, funcname: _subx
# re.py(309):     template = _compile_repl(template, pattern)
# re.py(310):     if not template[0] and len(template[1]) == 1:
# re.py(313):     def filter(match, template=template):
# re.py(315):     return filter
#  --- modulename: re, funcname: filter
# re.py(314):         return sre_parse.expand_template(template, match)
#  --- modulename: sre_parse, funcname: expand_template
# sre_parse.py(1037):     g = match.group
# sre_parse.py(1038):     empty = match.string[:0]
# sre_parse.py(1039):     groups, literals = template
# sre_parse.py(1040):     literals = literals[:]
# sre_parse.py(1041):     try:
# sre_parse.py(1042):         for index, group in groups:
# sre_parse.py(1043):             literals[index] = g(group) or empty
# sre_parse.py(1042):         for index, group in groups:
# sre_parse.py(1043):             literals[index] = g(group) or empty
# sre_parse.py(1042):         for index, group in groups:
# sre_parse.py(1046):     return empty.join(literals)
# basic_train.py(132):     if cls_name == 'mix_up_loss':
# basic_train.py(135):     if cls_name in loss_func_name2activ:
# basic_train.py(136):         if cls_name == 'poisson_nll_loss' and (not getattr(loss_func, 'log_input', True)): return
# basic_train.py(137):         return _loss_func_name2activ(cls_name, axis)
#  --- modulename: basic_train, funcname: _loss_func_name2activ
# basic_train.py(119):     res = loss_func_name2activ[name]
# basic_train.py(120):     if res == F.softmax: res = partial(F.softmax, dim=axis)
# basic_train.py(121):     return res
#  --- modulename: functional, funcname: softmax
# functional.py(992):     if dim is None:
# functional.py(994):     if dtype is None:
# functional.py(995):         return input.softmax(dim)
# basic_train.py(343):         if not reconstruct: return res
# basic_train.py(362):         pred,x = res[0],batch[0]
# basic_train.py(363):         norm = getattr(self.data,'norm',False)
#  --- modulename: basic_data, funcname: __getattr__
# basic_data.py(122):     def __getattr__(self,k:int)->Any: return getattr(self.train_dl, k)
#  --- modulename: basic_data, funcname: __getattr__
# basic_data.py(38):     def __getattr__(self,k:str)->Any: return getattr(self.dl, k)
#  --- modulename: basic_data, funcname: DataLoader___getattr__
# basic_data.py(20): def DataLoader___getattr__(dl, k:str)->Any: return getattr(dl.dataset, k)
#  --- modulename: data_block, funcname: __getattr__
# data_block.py(621):         x = super().__getattribute__('x')
# data_block.py(622):         res = getattr(x, k, None)
# data_block.py(623):         if res is not None and k not in ['classes', 'c']: return res
# data_block.py(624):         y = super().__getattribute__('y')
# data_block.py(625):         res = getattr(y, k, None)
# data_block.py(626):         if res is not None: return res
# data_block.py(627):         raise AttributeError(k)
# basic_train.py(364):         if norm:
# basic_train.py(367):         ds = self.data.single_ds
#  --- modulename: basic_data, funcname: single_ds
# basic_data.py(211):     def single_ds(self)->Dataset: return self._grab_dataset(self.single_dl)
#  --- modulename: basic_data, funcname: _grab_dataset
# basic_data.py(202):         ds = dl.dl.dataset
# basic_data.py(203):         while hasattr(ds, 'dataset'): ds = ds.dataset
#  --- modulename: data_block, funcname: __getattr__
# data_block.py(621):         x = super().__getattribute__('x')
# data_block.py(622):         res = getattr(x, k, None)
# data_block.py(623):         if res is not None and k not in ['classes', 'c']: return res
# data_block.py(624):         y = super().__getattribute__('y')
# data_block.py(625):         res = getattr(y, k, None)
# data_block.py(626):         if res is not None: return res
# data_block.py(627):         raise AttributeError(k)
# basic_data.py(204):         return ds
# basic_train.py(368):         pred = ds.y.analyze_pred(pred, **kwargs)
#  --- modulename: data_block, funcname: analyze_pred
# data_block.py(369):     def analyze_pred(self, pred, thresh:float=0.5): return pred.argmax()
#  --- modulename: tensor, funcname: argmax
# tensor.py(240):         return torch.argmax(self, dim, keepdim)
#  --- modulename: functional, funcname: argmax
# functional.py(529):     if dim is None:
# functional.py(530):         return torch._argmax(input.contiguous().view(-1), dim=0, keepdim=False)
# basic_train.py(369):         out = ds.y.reconstruct(pred, ds.x.reconstruct(x[0])) if has_arg(ds.y.reconstruct, 'x') else ds.y.reconstruct(pred)
#  --- modulename: core, funcname: has_arg
# core.py(258):     return arg in func_args(func)
#  --- modulename: core, funcname: func_args
# core.py(253):     code = func.__code__
# core.py(254):     return code.co_varnames[:code.co_argcount]
#  --- modulename: data_block, funcname: reconstruct
# data_block.py(372):         return Category(t, self.classes[t])
#  --- modulename: core, funcname: __init__
# core.py(282):     def __init__(self,data,obj): self.data,self.obj = data,obj
# basic_train.py(370):         return out, pred, res[0]
# (Category 3, tensor(0), tensor([0.5662, 0.4338]))

# %%
tracer.counts
# Out:
# {('/data/git/fastai/fastai/basic_train.py', 190): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 182): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 183): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 184): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 185): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 191): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 192): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 193): 1,
#  ('/data/git/fastai/fastai/callback.py', 80): 1,
#  ('/data/git/fastai/fastai/core.py', 104): 5,
#  ('/data/git/fastai/fastai/core.py', 105): 4,
#  ('/data/git/fastai/fastai/core.py', 106): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/abc.py', 139): 66,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/abc.py', 143): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 254): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 255): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 73): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 74): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 75): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 76): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 77): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 79): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 82): 1,
#  ('/data/git/fastai/fastai/core.py', 109): 3,
#  ('/data/git/fastai/fastai/core.py', 111): 5,
#  ('/data/git/fastai/fastai/core.py', 112): 5,
#  ('/data/git/fastai/fastai/core.py', 113): 5,
#  ('/data/git/fastai/fastai/core.py', 114): 5,
#  ('/data/git/fastai/fastai/callback.py', 133): 1,
#  ('/data/git/fastai/fastai/core.py', 52): 1,
#  ('/data/git/fastai/fastai/callback.py', 134): 4,
#  ('/data/git/fastai/fastai/callback.py', 135): 3,
#  ('/data/git/fastai/fastai/callback.py', 136): 3,
#  ('/data/git/fastai/fastai/callback.py', 137): 1,
#  ('/data/git/fastai/fastai/callback.py', 105): 1,
#  ('/data/git/fastai/fastai/callback.py', 106): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 194): 3,
#  ('/data/git/fastai/fastai/basic_train.py', 437): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 418): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 419): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 420): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 426): 4,
#  ('/data/git/fastai/fastai/basic_train.py', 431): 1,
#  ('/data/git/fastai/fastai/core.py', 120): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 192): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 273): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 275): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 276): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 277): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 278): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 279): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 280): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 283): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 309): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 300): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 954): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 225): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 226): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 227): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 229): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 230): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 231): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 232): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 234): 10,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 235): 10,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 236): 10,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 240): 6,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 241): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 242): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 243): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 247): 6,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 248): 6,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 955): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 956): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 957): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 958): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 959): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 960): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 968): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 969): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 970): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 255): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 256): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 257): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 971): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 973): 6,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 975): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 976): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 998): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 1004): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 1005): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 1006): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 1017): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 1018): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 961): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 963): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 966): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 967): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 1027): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 237): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 238): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 239): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 964): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 965): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 972): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 1028): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 1030): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/sre_parse.py', 1034): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 310): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 313): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/re.py', 315): 4,
#  ('/data/git/fastai/fastai/core.py', 121): 2,
#  ('/data/git/fastai/fastai/basic_train.py', 438): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 439): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 440): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 195): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 196): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 86): 1,
#  ('/data/git/fastai/fastai/basic_data.py', 37): 3,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   822): 3,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/sampler.py',
#   169): 3,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/sampler.py',
#   170): 3,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/sampler.py',
#   76): 3,
#  ('/data/git/fastai/fastai/data_block.py', 591): 5,
#  ('/data/git/fastai/fastai/data_block.py', 63): 4,
#  ('/data/git/fastai/fastai/basic_train.py', 88): 1,
#  ('/data/git/fastai/fastai/callback.py', 231): 3,
#  ('/data/git/fastai/fastai/core.py', 67): 16,
#  ('/data/git/fastai/fastai/callback.py', 232): 3,
#  ('/data/git/fastai/fastai/callback.py', 233): 7,
#  ('/data/git/fastai/fastai/callback.py', 328): 1,
#  ('/data/git/fastai/fastai/callback.py', 329): 1,
#  ('/data/git/fastai/fastai/callback.py', 330): 1,
#  ('/data/git/fastai/fastai/torch_core.py', 395): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 659): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 660): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/os.py', 674): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/os.py', 675): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/os.py', 752): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/os.py', 754): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/os.py', 676): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/os.py', 678): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 661): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_collections_abc.py', 662): 1,
#  ('/data/git/fastai/fastai/callback.py', 234): 4,
#  ('/data/git/fastai/fastai/callback.py', 235): 3,
#  ('/data/git/fastai/fastai/callback.py', 210): 3,
#  ('/data/git/fastai/fastai/callback.py', 236): 3,
#  ('/data/git/fastai/fastai/callback.py', 220): 4,
#  ('/data/git/fastai/fastai/basic_train.py', 89): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   175): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   102): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   151): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   116): 6,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   134): 6,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   152): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   44): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   45): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   46): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   47): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   48): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   52): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   53): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   176): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   177): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   178): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   179): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   180): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   181): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 90): 1,
#  ('/data/git/fastai/fastai/callback.py', 261): 1,
#  ('/data/git/fastai/fastai/callback.py', 262): 1,
#  ('/data/git/fastai/fastai/callback.py', 263): 3,
#  ('/data/git/fastai/fastai/callback.py', 264): 1,
#  ('/data/git/fastai/fastai/callback.py', 248): 5,
#  ('/data/git/fastai/fastai/callback.py', 249): 7,
#  ('/data/git/fastai/fastai/callback.py', 240): 6,
#  ('/data/git/fastai/fastai/callback.py', 163): 1,
#  ('/data/git/fastai/fastai/callback.py', 241): 6,
#  ('/data/git/fastai/fastai/callback.py', 250): 8,
#  ('/data/git/fastai/fastai/basic_train.py', 444): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 445): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 446): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 447): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 422): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 448): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 449): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   211): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   213): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   214): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   138): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   139): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   140): 6,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   141): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   142): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   146): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   147): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 450): 1,
#  ('/data/git/fastai/fastai/callback.py', 265): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 92): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 93): 1,
#  ('/data/git/fastai/fastai/basic_train.py', 94): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   105): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   184): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   109): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/fastprogress/fastprogress.py',
#   185): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   676): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   688): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   677): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   684): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   685): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   686): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   690): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   596): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   597): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   601): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   34): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   35): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/genericpath.py', 18): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/genericpath.py', 19): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/genericpath.py', 20): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/genericpath.py', 21): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   606): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   607): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   608): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   610): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   612): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   613): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   615): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   639): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   642): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   616): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   664): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   276): 4,
#  ('<frozen importlib._bootstrap>', 1019): 69,
#  ('<frozen importlib._bootstrap>', 1044): 69,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   278): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/traitlets/config/configurable.py',
#   429): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   283): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   284): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   285): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   286): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   287): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   288): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   289): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   290): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   126): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   291): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   292): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   294): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   295): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   297): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   298): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/traitlets/config/configurable.py',
#   411): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/traitlets/config/configurable.py',
#   418): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/traitlets/config/configurable.py',
#   419): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/traitlets/traitlets.py',
#   553): 617,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/traitlets/traitlets.py',
#   556): 617,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/traitlets/traitlets.py',
#   527): 617,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/traitlets/traitlets.py',
#   528): 617,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/traitlets/traitlets.py',
#   543): 616,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   300): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   301): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   304): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   143): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   144): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   146): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   223): 48,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   224): 48,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   906): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   908): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   909): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   391): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   392): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   395): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   276): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   413): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   424): 220,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   317): 48,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   328): 48,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   329): 48,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   425): 176,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   556): 176,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   557): 176,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   558): 176,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   559): 176,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   564): 176,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   429): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   910): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   911): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   916): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/utils/dir2.py',
#   64): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/utils/dir2.py',
#   65): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/utils/dir2.py',
#   69): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/utils/dir2.py',
#   73): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/utils/dir2.py',
#   74): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/utils/dir2.py',
#   78): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/inspect.py', 78): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/utils/dir2.py',
#   81): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/utils/dir2.py',
#   84): 40,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   917): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   236): 48,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   364): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   366): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   150): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   958): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   960): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   961): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   962): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   963): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   967): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   969): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   971): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   941): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   943): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   944): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   152): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   160): 44,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   161): 40,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   173): 40,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   175): 40,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   178): 40,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   179): 40,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   180): 40,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   692): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   695): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   696): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   697): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   698): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   699): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   700): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   701): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   351): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   189): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   190): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   191): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   192): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   193): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   194): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   195): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   197): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   475): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   476): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   477): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   198): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   199): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   483): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   484): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   485): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   488): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   489): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   490): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   491): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   200): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   352): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   353): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   354): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   356): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   357): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   359): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   360): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   362): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   702): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   366): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   367): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   368): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   369): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   279): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   281): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   282): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   283): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   284): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   370): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   371): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   111): 28,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   112): 28,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   373): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   374): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   375): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   376): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   382): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   383): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   388): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   417): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   418): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   419): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   420): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   421): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   425): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   389): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   396): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   400): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   401): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   402): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   697): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   619): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   620): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   621): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   624): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   698): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   699): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   701): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   218): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   219): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   228): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   229): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   406): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   298): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   299): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   300): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   301): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   505): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   506): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   302): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   407): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   703): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   307): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   309): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/lib/pretty.py',
#   310): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   704): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   186): 40,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   189): 40,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   190): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   191): 40,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   334): 36,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   336): 36,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   337): 36,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   338): 36,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   339): 36,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   343): 36,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/utils/dir2.py',
#   82): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   344): 36,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   345): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   693): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   632): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   635): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   346): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   829): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   830): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/formatters.py',
#   193): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   305): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   308): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   311): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   107): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   109): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   114): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   115): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   117): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   118): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   119): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/display.py',
#   120): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   112): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   79): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/iostream.py',
#   339): 24,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 1088): 103,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 1089): 103,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 509): 121,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 1091): 103,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 1045): 103,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 1046): 103,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 1048): 103,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 1092): 103,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/iostream.py',
#   341): 24,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/iostream.py',
#   200): 52,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/iostream.py',
#   201): 52,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/iostream.py',
#   203): 52,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/iostream.py',
#   96): 52,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/iostream.py',
#   97): 52,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/iostream.py',
#   105): 52,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/zmq/sugar/socket.py',
#   382): 52,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/zmq/sugar/socket.py',
#   387): 52,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/zmq/sugar/socket.py',
#   392): 52,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/iostream.py',
#   345): 24,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/iostream.py',
#   346): 24,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 500): 33,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 217): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 219): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 221): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 222): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 226): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 227): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 228): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 229): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 230): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 231): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 232): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 233): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 234): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 235): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 236): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 237): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 238): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 501): 33,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/iostream.py',
#   347): 24,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/iostream.py',
#   349): 24,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 549): 33,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 241): 76,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 550): 33,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 551): 33,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 552): 26,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 287): 53,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 258): 69,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 262): 69,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 289): 53,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 290): 53,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 291): 53,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 292): 53,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 250): 53,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 293): 53,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 294): 53,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 295): 53,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 299): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 300): 45,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 303): 52,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 305): 53,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 253): 53,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 306): 53,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 553): 33,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/threading.py', 244): 76,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   80): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   113): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   115): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   117): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/displaypub.py',
#   49): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/displaypub.py',
#   51): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/IPython/core/displaypub.py',
#   52): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   118): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   119): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   73): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   74): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   120): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   121): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   123): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   128): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   129): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   133): 28,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   136): 28,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   141): 28,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   144): 28,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   148): 28,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   154): 28,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   157): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   172): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   173): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   176): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   179): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   183): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   184): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   185): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   189): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   190): 40,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipython_genutils/py3compat.py',
#   188): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   191): 24,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   155): 12,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/jsonutil.py',
#   192): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/ipykernel/zmqshell.py',
#   130): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/jupyter_client/session.py',
#   571): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/jupyter_client/session.py',
#   572): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/jupyter_client/session.py',
#   562): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/jupyter_client/session.py',
#   512): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/jupyter_client/session.py',
#   131): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/jupyter_client/session.py',
# ...
#   526): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   528): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   530): 2,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   531): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   532): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   533): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   101): 9,
#  ('<frozen importlib._bootstrap>', 419): 62,
#  ('<frozen importlib._bootstrap>', 420): 62,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   102): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   233): 18,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   234): 18,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   236): 18,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   37): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   39): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   40): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   41): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/connection.py',
#   510): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/connection.py',
#   517): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/connection.py',
#   518): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/connection.py',
#   118): 18,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/connection.py',
#   119): 18,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/connection.py',
#   121): 18,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/connection.py',
#   124): 18,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/connection.py',
#   125): 18,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/connection.py',
#   126): 18,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/connection.py',
#   519): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/connection.py',
#   521): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   42): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   66): 19,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   67): 19,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   187): 33,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   188): 33,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   162): 19,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   51): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   53): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   197): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   54): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   55): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   56): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   57): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   58): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   116): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   40): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   117): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/tempfile.py', 154): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/tempfile.py', 155): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/tempfile.py', 144): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/tempfile.py', 145): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/tempfile.py', 148): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/tempfile.py', 156): 320,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/random.py', 258): 256,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/random.py', 259): 256,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/random.py', 228): 256,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/random.py', 229): 256,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/random.py', 232): 256,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/random.py', 233): 256,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/random.py', 234): 256,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/random.py', 235): 436,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/random.py', 237): 256,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/random.py', 262): 256,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/random.py', 236): 180,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/tempfile.py', 157): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   59): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   63): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   67): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/util.py',
#   49): 73,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   68): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   91): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   92): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   70): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   71): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   73): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/util.py',
#   137): 41,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/weakref.py', 166): 41,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/weakref.py', 168): 41,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/weakref.py', 335): 41,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/weakref.py', 336): 41,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/weakref.py', 337): 41,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/weakref.py', 340): 41,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   75): 32,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   43): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   44): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   47): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   48): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   86): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   87): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   145): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   50): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   52): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   68): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   69): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   70): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   71): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   72): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   73): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   74): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   75): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   76): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   77): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   78): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   54): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   55): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   534): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   535): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   536): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   537): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   538): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   539): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   540): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   91): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   92): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   324): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   76): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   77): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   213): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   214): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   81): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   82): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   126): 4,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   215): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   216): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   217): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   236): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   237): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/synchronize.py',
#   325): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   542): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   543): 1,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   544): 9,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   545): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   546): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   148): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   149): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   150): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   151): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   152): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/queues.py',
#   153): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   547): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   548): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   549): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   550): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   551): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   552): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   74): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   75): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   76): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   77): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   78): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   79): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   80): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   81): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   82): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   83): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   84): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   85): 24,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   86): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   88): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_weakrefset.py', 82): 17,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/_weakrefset.py', 84): 17,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   553): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   201): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   202): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/site-packages/torch/utils/data/dataloader.py',
#   560): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   105): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   91): 16,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   106): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   107): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   109): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   111): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   55): 36,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/process.py',
#   112): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   223): 8,
#  ('/data/anaconda3/envs/fastaidev/lib/python3.7/multiprocessing/context.py',
#   276): 8,
#  ('<frozen importlib._bootstrap>', 980): 1,
#  ('<frozen importlib._bootstrap>', 144): 1,
#  ('<frozen importlib._bootstrap>', 145): 1,
#  ('<frozen importlib._bootstrap>', 148): 1,
#  ('<frozen importlib._bootstrap>', 163): 1,
#  ('<frozen importlib._bootstrap>', 164): 1,
#  ('<frozen importlib._bootstrap>', 165): 1,
#  ('<frozen importlib._bootstrap>', 166): 1,
#  ('<frozen importlib._bootstrap>', 167): 1,
#  ('<frozen importlib._bootstrap>', 168): 1,
#  ('<frozen importlib._bootstrap>', 170): 1,
#  ('<frozen importlib._bootstrap>', 171): 1,
#  ('<frozen importlib._bootstrap>', 174): 1,
#  ('<frozen importlib._bootstrap>', 59): 1,
#  ('<frozen importlib._bootstrap>', 60): 1,
#  ('<frozen importlib._bootstrap>', 61): 1,
#  ('<frozen importlib._bootstrap>', 62): 1,
#  ('<frozen importlib._bootstrap>', 63): 1,
#  ...}
