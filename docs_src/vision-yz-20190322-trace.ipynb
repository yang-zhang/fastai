# %% [markdown]
# ## Computer vision

# %%
from fastai.gen_doc.nbdoc import *

# %% [markdown]
# The [`vision`](/vision.html#vision) module of the fastai library contains all the necessary functions to define a Dataset and train a model for computer vision tasks. It contains four different submodules to reach that goal:
# - [`vision.image`](/vision.image.html#vision.image) contains the basic definition of an [`Image`](/vision.image.html#Image) object and all the functions that are used behind the scenes to apply transformations to such an object.
# - [`vision.transform`](/vision.transform.html#vision.transform) contains all the transforms we can use for data augmentation.
# - [`vision.data`](/vision.data.html#vision.data) contains the definition of [`ImageDataBunch`](/vision.data.html#ImageDataBunch) as well as the utility function to easily build a [`DataBunch`](/basic_data.html#DataBunch) for Computer Vision problems.
# - [`vision.learner`](/vision.learner.html#vision.learner) lets you build and fine-tune models with a pretrained CNN backbone or train a randomly initialized model from scratch.
#
# Each of the four module links above includes a quick overview and examples of the functionality of that module, as well as complete API documentation. Below, we'll provide a walk-thru of end to end computer vision model training with the most commonly used functionality.

# %% [markdown]
# ## Minimal training example

# %% [markdown]
# First, import everything you need from the fastai library.

# %%
from fastai.vision import *

# %% [markdown]
# First, create a data folder containing a MNIST subset in `data/mnist_sample` using this little helper that will download it for you:

# %%
path = untar_data(URLs.MNIST_SAMPLE)
path
# Out:
# PosixPath('/Users/yang.zhang/.fastai/data/mnist_sample')

# %% [markdown]
# Since this contains standard [`train`](/train.html#train) and `valid` folders, and each contains one folder per class, you can create a [`DataBunch`](/basic_data.html#DataBunch) in a single line:

# %%
data = ImageDataBunch.from_folder(path)

# %% [markdown]
# You load a pretrained model (from [`vision.models`](/vision.models.html#vision.models)) ready for fine tuning:

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)

# %%
learn.fit(1)
# Out:
# Total time: 02:24 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.139883</td>
#       <td>0.091072</td>
#       <td>0.969578</td>
#       <td>02:24</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# And now you're ready to train!

# %%
import trace

# %% [markdown]
# https://docs.python.org/3.7/library/trace.html#programmatic-interface

# %%
tracer = trace.Trace(ignoredirs=[sys.prefix, sys.exec_prefix])

# %% [markdown]
# ### trace fit

# %%
# learn.fit(1)
tracer.runfunc(learn.fit, 1)

# %% [markdown]
# ### trace predict

# %%
img = learn.data.train_ds[0][0]
# learn.predict(img)

tracer.runfunc(learn.predict, img)
# Out:
#  --- modulename: basic_train, funcname: predict
# basic_train.py(360):         batch = self.data.one_item(item)
#  --- modulename: basic_data, funcname: one_item
# basic_data.py(179):         ds = self.single_ds
#  --- modulename: basic_data, funcname: single_ds
# basic_data.py(211):     def single_ds(self)->Dataset: return self._grab_dataset(self.single_dl)
#  --- modulename: basic_data, funcname: _grab_dataset
# basic_data.py(202):         ds = dl.dl.dataset
# basic_data.py(203):         while hasattr(ds, 'dataset'): ds = ds.dataset
#  --- modulename: data_block, funcname: __getattr__
# data_block.py(621):         x = super().__getattribute__('x')
# data_block.py(622):         res = getattr(x, k, None)
# data_block.py(623):         if res is not None and k not in ['classes', 'c']: return res
# data_block.py(624):         y = super().__getattribute__('y')
# data_block.py(625):         res = getattr(y, k, None)
# data_block.py(626):         if res is not None: return res
# data_block.py(627):         raise AttributeError(k)
# basic_data.py(204):         return ds
# basic_data.py(180):         with ds.set_item(item):
#  --- modulename: data_block, funcname: set_item
# data_block.py(596):         self.item = self.x.process_one(item)
#  --- modulename: data_block, funcname: process_one
# data_block.py(80):         if processor is not None: self.processor = processor
# data_block.py(81):         self.processor = listify(self.processor)
#  --- modulename: core, funcname: listify
# core.py(104):     if p is None: p=[]
# core.py(105):     elif isinstance(p, str):          p = [p]
# core.py(106):     elif not isinstance(p, Iterable): p = [p]
# core.py(109):         try: a = len(p)
# core.py(111):     n = q if type(q)==int else len(p) if q is None else len(q)
# core.py(112):     if len(p)==1: p = p * n
# core.py(113):     assert len(p)==n, f'List len mismatch ({len(p)} vs {n})'
# core.py(114):     return list(p)
# data_block.py(82):         for p in self.processor: item = p.process_one(item)
# data_block.py(83):         return item
# data_block.py(597):         yield None
# basic_data.py(181):             return self.one_batch(ds_type=DatasetType.Single, detach=detach, denorm=denorm, cpu=cpu)
#  --- modulename: basic_data, funcname: one_batch
# basic_data.py(165):         dl = self.dl(ds_type)
#  --- modulename: basic_data, funcname: dl
# basic_data.py(128):         return (self.train_dl if ds_type == DatasetType.Train else
# basic_data.py(129):                 self.test_dl if ds_type == DatasetType.Test else
# basic_data.py(130):                 self.valid_dl if ds_type == DatasetType.Valid else
# basic_data.py(131):                 self.single_dl if ds_type == DatasetType.Single else
# basic_data.py(166):         w = self.num_workers
#  --- modulename: basic_data, funcname: __getattr__
# basic_data.py(122):     def __getattr__(self,k:int)->Any: return getattr(self.train_dl, k)
#  --- modulename: basic_data, funcname: num_workers
# basic_data.py(50):     def num_workers(self):   return self.dl.num_workers
# basic_data.py(167):         self.num_workers = 0
# basic_data.py(168):         try:     x,y = next(iter(dl))
#  --- modulename: basic_data, funcname: __iter__
# basic_data.py(75):         for b in self.dl: yield self.proc_batch(b)
#  --- modulename: data_block, funcname: __len__
# data_block.py(591):     def __len__(self)->int: return len(self.x) if self.item is None else 1
#  --- modulename: data_block, funcname: __getitem__
# data_block.py(632):         idxs = try_int(idxs)
#  --- modulename: torch_core, funcname: try_int
# torch_core.py(367):     if isinstance(o, (np.ndarray,Tensor)): return o if o.ndim else int(o)
# torch_core.py(368):     if isinstance(o, collections.Sized) or getattr(o,'__array_interface__',False): return o
# torch_core.py(369):     try: return int(o)
# data_block.py(633):         if isinstance(idxs, Integral):
# data_block.py(634):             if self.item is None: x,y = self.x[idxs],self.y[idxs]
# data_block.py(635):             else:                 x,y = self.item   ,0
# data_block.py(636):             if self.tfms or self.tfmargs:
# data_block.py(637):                 x = x.apply_tfms(self.tfms, **self.tfmargs)
#  --- modulename: image, funcname: apply_tfms
# image.py(100):         if not (tfms or xtra or size): return self
# data_block.py(638):             if hasattr(self, 'tfms_y') and self.tfm_y and self.item is None:
# data_block.py(640):             if y is None: y=0
# data_block.py(641):             return x,y
#  --- modulename: torch_core, funcname: data_collate
# torch_core.py(126):     return torch.utils.data.dataloader.default_collate(to_data(batch))
#  --- modulename: torch_core, funcname: to_data
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
#  --- modulename: torch_core, funcname: <listcomp>
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: torch_core, funcname: to_data
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
#  --- modulename: torch_core, funcname: <listcomp>
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: torch_core, funcname: to_data
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
# torch_core.py(100):     return b.data if isinstance(b,ItemBase) else b
#  --- modulename: image, funcname: data
# image.py(214):         return self.px
#  --- modulename: image, funcname: px
# image.py(145):         self.refresh()
#  --- modulename: image, funcname: refresh
# image.py(128):         if self._logit_px is not None:
# image.py(131):         if self._affine_mat is not None or self._flow is not None:
# image.py(135):         return self
# image.py(146):         return self._px
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: torch_core, funcname: to_data
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
# torch_core.py(100):     return b.data if isinstance(b,ItemBase) else b
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
# torch_core.py(99):     if is_listy(b): return [to_data(o) for o in b]
#  --- modulename: basic_data, funcname: proc_batch
# basic_data.py(69):         b = to_device(b, self.device)
#  --- modulename: torch_core, funcname: to_device
# torch_core.py(119):     device = ifnone(device, defaults.device)
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# torch_core.py(120):     if is_listy(b): return [to_device(o, device) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
#  --- modulename: torch_core, funcname: <listcomp>
# torch_core.py(120):     if is_listy(b): return [to_device(o, device) for o in b]
#  --- modulename: torch_core, funcname: to_device
# torch_core.py(119):     device = ifnone(device, defaults.device)
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# torch_core.py(120):     if is_listy(b): return [to_device(o, device) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
# torch_core.py(121):     if is_dict(b): return {k: to_device(v, device) for k, v in b.items()}
#  --- modulename: core, funcname: is_dict
# core.py(53): def is_dict(x:Any)->bool: return isinstance(x, dict)
# torch_core.py(122):     return b.to(device, non_blocking=True)
# torch_core.py(120):     if is_listy(b): return [to_device(o, device) for o in b]
#  --- modulename: torch_core, funcname: to_device
# torch_core.py(119):     device = ifnone(device, defaults.device)
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# torch_core.py(120):     if is_listy(b): return [to_device(o, device) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
# torch_core.py(121):     if is_dict(b): return {k: to_device(v, device) for k, v in b.items()}
#  --- modulename: core, funcname: is_dict
# core.py(53): def is_dict(x:Any)->bool: return isinstance(x, dict)
# torch_core.py(122):     return b.to(device, non_blocking=True)
# torch_core.py(120):     if is_listy(b): return [to_device(o, device) for o in b]
# basic_data.py(70):         for f in listify(self.tfms): b = f(b)
#  --- modulename: core, funcname: listify
# core.py(104):     if p is None: p=[]
# core.py(105):     elif isinstance(p, str):          p = [p]
# core.py(106):     elif not isinstance(p, Iterable): p = [p]
# core.py(109):         try: a = len(p)
# core.py(111):     n = q if type(q)==int else len(p) if q is None else len(q)
# core.py(112):     if len(p)==1: p = p * n
# core.py(113):     assert len(p)==n, f'List len mismatch ({len(p)} vs {n})'
# core.py(114):     return list(p)
# basic_data.py(71):         return b
#  --- modulename: basic_data, funcname: __iter__
# basic_data.py(169):         finally: self.num_workers = w
# basic_data.py(170):         if detach: x,y = to_detach(x,cpu=cpu),to_detach(y,cpu=cpu)
# basic_data.py(171):         norm = getattr(self,'norm',False)
#  --- modulename: basic_data, funcname: __getattr__
# basic_data.py(122):     def __getattr__(self,k:int)->Any: return getattr(self.train_dl, k)
#  --- modulename: basic_data, funcname: __getattr__
# basic_data.py(38):     def __getattr__(self,k:str)->Any: return getattr(self.dl, k)
#  --- modulename: basic_data, funcname: DataLoader___getattr__
# basic_data.py(20): def DataLoader___getattr__(dl, k:str)->Any: return getattr(dl.dataset, k)
#  --- modulename: data_block, funcname: __getattr__
# data_block.py(621):         x = super().__getattribute__('x')
# data_block.py(622):         res = getattr(x, k, None)
# data_block.py(623):         if res is not None and k not in ['classes', 'c']: return res
# data_block.py(624):         y = super().__getattribute__('y')
# data_block.py(625):         res = getattr(y, k, None)
# data_block.py(626):         if res is not None: return res
# data_block.py(627):         raise AttributeError(k)
# basic_data.py(172):         if denorm and norm:
# basic_data.py(175):         return x,y
#  --- modulename: data_block, funcname: set_item
# data_block.py(598):         self.item = None
# basic_train.py(361):         res = self.pred_batch(batch=batch)
#  --- modulename: basic_train, funcname: pred_batch
# basic_train.py(337):         if batch is not None: xb,yb = batch
# basic_train.py(339):         cb_handler = CallbackHandler(self.callbacks)
#  --- modulename: callback, funcname: __post_init__
# callback.py(231):         self.callbacks = ifnone(self.callbacks, [])
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# callback.py(232):         self.metrics = ifnone(self.metrics, [])
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# callback.py(233):         self.metrics = [(met if isinstance(met, Callback) else AverageMetric(met)) for met in self.metrics]
#  --- modulename: callback, funcname: <listcomp>
# callback.py(233):         self.metrics = [(met if isinstance(met, Callback) else AverageMetric(met)) for met in self.metrics]
# callback.py(234):         self.callbacks = sorted(self.callbacks, key=lambda o: getattr(o, '_order', 0))
# callback.py(235):         self.smoothener = SmoothenValue(self.beta)
#  --- modulename: callback, funcname: __init__
# callback.py(210):         self.beta,self.n,self.mov_avg = beta,0,0
# callback.py(236):         self.state_dict:Dict[str,Union[int,float,Tensor]]=_get_init_state()
#  --- modulename: callback, funcname: _get_init_state
# callback.py(220): def _get_init_state(): return {'epoch':0, 'iteration':0, 'num_batch':0}
# basic_train.py(340):         xb,yb = cb_handler.on_batch_begin(xb,yb, train=False)
#  --- modulename: callback, funcname: on_batch_begin
# callback.py(276):         self.state_dict.update(dict(last_input=xb, last_target=yb, train=train,
# callback.py(277):             stop_epoch=False, skip_step=False, skip_zero=False, skip_bwd=False))
# callback.py(278):         self('batch_begin', mets = not self.state_dict['train'])
#  --- modulename: callback, funcname: __call__
# callback.py(248):         if call_mets:
# callback.py(249):             for met in self.metrics: self._call_and_update(met, cb_name, **kwargs)
# callback.py(250):         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
# callback.py(279):         return self.state_dict['last_input'], self.state_dict['last_target']
# basic_train.py(341):         preds = loss_batch(self.model.eval(), xb, yb, cb_handler=cb_handler)
#  --- modulename: basic_train, funcname: loss_batch
# basic_train.py(22):     cb_handler = ifnone(cb_handler, CallbackHandler())
#  --- modulename: callback, funcname: __post_init__
# callback.py(231):         self.callbacks = ifnone(self.callbacks, [])
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# callback.py(232):         self.metrics = ifnone(self.metrics, [])
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# callback.py(233):         self.metrics = [(met if isinstance(met, Callback) else AverageMetric(met)) for met in self.metrics]
#  --- modulename: callback, funcname: <listcomp>
# callback.py(233):         self.metrics = [(met if isinstance(met, Callback) else AverageMetric(met)) for met in self.metrics]
# callback.py(234):         self.callbacks = sorted(self.callbacks, key=lambda o: getattr(o, '_order', 0))
# callback.py(235):         self.smoothener = SmoothenValue(self.beta)
#  --- modulename: callback, funcname: __init__
# callback.py(210):         self.beta,self.n,self.mov_avg = beta,0,0
# callback.py(236):         self.state_dict:Dict[str,Union[int,float,Tensor]]=_get_init_state()
#  --- modulename: callback, funcname: _get_init_state
# callback.py(220): def _get_init_state(): return {'epoch':0, 'iteration':0, 'num_batch':0}
#  --- modulename: core, funcname: ifnone
# core.py(67):     return b if a is None else a
# basic_train.py(23):     if not is_listy(xb): xb = [xb]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
# basic_train.py(24):     if not is_listy(yb): yb = [yb]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
# basic_train.py(25):     out = model(*xb)
#  --- modulename: layers, funcname: forward
# layers.py(191):     def forward(self, x): return torch.cat([self.mp(x), self.ap(x)], 1)
#  --- modulename: layers, funcname: forward
# layers.py(44):         return x.view(-1) if self.full else x.view(x.size(0), -1)
# basic_train.py(26):     out = cb_handler.on_loss_begin(out)
#  --- modulename: callback, funcname: on_loss_begin
# callback.py(283):         self.state_dict['last_output'] = out
# callback.py(284):         self('loss_begin', call_mets=False)
#  --- modulename: callback, funcname: __call__
# callback.py(248):         if call_mets:
# callback.py(250):         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
# callback.py(285):         return self.state_dict['last_output']
# basic_train.py(28):     if not loss_func: return to_detach(out), yb[0].detach()
#  --- modulename: torch_core, funcname: to_detach
# torch_core.py(92):     if is_listy(b): return [to_detach(o, cpu) for o in b]
#  --- modulename: core, funcname: is_listy
# core.py(51): def is_listy(x:Any)->bool: return isinstance(x, (tuple,list))
# torch_core.py(93):     if not isinstance(b,Tensor): return b
# torch_core.py(94):     b = b.detach()
# torch_core.py(95):     return b.cpu() if cpu else b
# basic_train.py(342):         res = _loss_func2activ(self.loss_func)(preds[0])
#  --- modulename: basic_train, funcname: _loss_func2activ
# basic_train.py(124):     if getattr(loss_func,'keywords',None):
# basic_train.py(126):     axis = getattr(loss_func, 'axis', -1)
# basic_train.py(128):     loss_func = getattr(loss_func, 'func', loss_func)
# basic_train.py(130):     loss_func = getattr(loss_func, 'func', loss_func)
# basic_train.py(131):     cls_name = camel2snake(loss_func.__class__.__name__)
#  --- modulename: core, funcname: camel2snake
# core.py(120):     s1 = re.sub(_camel_re1, r'\1_\2', name)
# core.py(121):     return re.sub(_camel_re2, r'\1_\2', s1).lower()
# basic_train.py(132):     if cls_name == 'mix_up_loss':
# basic_train.py(135):     if cls_name in loss_func_name2activ:
# basic_train.py(136):         if cls_name == 'poisson_nll_loss' and (not getattr(loss_func, 'log_input', True)): return
# basic_train.py(137):         return _loss_func_name2activ(cls_name, axis)
#  --- modulename: basic_train, funcname: _loss_func_name2activ
# basic_train.py(119):     res = loss_func_name2activ[name]
# basic_train.py(120):     if res == F.softmax: res = partial(F.softmax, dim=axis)
# basic_train.py(121):     return res
# basic_train.py(343):         if not reconstruct: return res
# basic_train.py(362):         pred,x = res[0],batch[0]
# basic_train.py(363):         norm = getattr(self.data,'norm',False)
#  --- modulename: basic_data, funcname: __getattr__
# basic_data.py(122):     def __getattr__(self,k:int)->Any: return getattr(self.train_dl, k)
#  --- modulename: basic_data, funcname: __getattr__
# basic_data.py(38):     def __getattr__(self,k:str)->Any: return getattr(self.dl, k)
#  --- modulename: basic_data, funcname: DataLoader___getattr__
# basic_data.py(20): def DataLoader___getattr__(dl, k:str)->Any: return getattr(dl.dataset, k)
#  --- modulename: data_block, funcname: __getattr__
# data_block.py(621):         x = super().__getattribute__('x')
# data_block.py(622):         res = getattr(x, k, None)
# data_block.py(623):         if res is not None and k not in ['classes', 'c']: return res
# data_block.py(624):         y = super().__getattribute__('y')
# data_block.py(625):         res = getattr(y, k, None)
# data_block.py(626):         if res is not None: return res
# data_block.py(627):         raise AttributeError(k)
# basic_train.py(364):         if norm:
# basic_train.py(367):         ds = self.data.single_ds
#  --- modulename: basic_data, funcname: single_ds
# basic_data.py(211):     def single_ds(self)->Dataset: return self._grab_dataset(self.single_dl)
#  --- modulename: basic_data, funcname: _grab_dataset
# basic_data.py(202):         ds = dl.dl.dataset
# basic_data.py(203):         while hasattr(ds, 'dataset'): ds = ds.dataset
#  --- modulename: data_block, funcname: __getattr__
# data_block.py(621):         x = super().__getattribute__('x')
# data_block.py(622):         res = getattr(x, k, None)
# data_block.py(623):         if res is not None and k not in ['classes', 'c']: return res
# data_block.py(624):         y = super().__getattribute__('y')
# data_block.py(625):         res = getattr(y, k, None)
# data_block.py(626):         if res is not None: return res
# data_block.py(627):         raise AttributeError(k)
# basic_data.py(204):         return ds
# basic_train.py(368):         pred = ds.y.analyze_pred(pred, **kwargs)
#  --- modulename: data_block, funcname: analyze_pred
# data_block.py(369):     def analyze_pred(self, pred, thresh:float=0.5): return pred.argmax()
# basic_train.py(369):         out = ds.y.reconstruct(pred, ds.x.reconstruct(x[0])) if has_arg(ds.y.reconstruct, 'x') else ds.y.reconstruct(pred)
#  --- modulename: core, funcname: has_arg
# core.py(258):     return arg in func_args(func)
#  --- modulename: core, funcname: func_args
# core.py(253):     code = func.__code__
# core.py(254):     return code.co_varnames[:code.co_argcount]
#  --- modulename: data_block, funcname: reconstruct
# data_block.py(372):         return Category(t, self.classes[t])
#  --- modulename: core, funcname: __init__
# core.py(282):     def __init__(self,data,obj): self.data,self.obj = data,obj
# basic_train.py(370):         return out, pred, res[0]
# (Category 7, tensor(1), tensor([4.2224e-04, 9.9958e-01]))

# %%
tracer.counts
# Out:
# {('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 360): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 179): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 211): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 202): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 203): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 621): 4,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 622): 4,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 623): 4,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 624): 4,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 625): 4,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 626): 4,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 627): 4,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 204): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 180): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 596): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 80): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 81): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 104): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 105): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 106): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 109): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 111): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 112): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 113): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 114): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 82): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 83): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 597): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 181): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 165): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 128): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 129): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 130): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 131): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 166): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 122): 3,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 50): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 167): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 168): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 75): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 591): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 632): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 367): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 368): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 369): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 633): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 634): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 635): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 636): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 637): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/vision/image.py', 100): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 638): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 640): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 641): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 126): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 99): 9,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 51): 10,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 100): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/vision/image.py', 214): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/vision/image.py', 145): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/vision/image.py', 128): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/vision/image.py', 131): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/vision/image.py', 135): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/vision/image.py', 146): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 69): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 119): 3,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 67): 8,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 120): 6,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 121): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 53): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 122): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 70): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 71): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 169): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 170): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 171): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 38): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 20): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 172): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_data.py', 175): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 598): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 361): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 337): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 339): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 231): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 232): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 233): 4,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 234): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 235): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 210): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 236): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 220): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 340): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 276): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 277): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 278): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 248): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 249): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 250): 2,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 279): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 341): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 22): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 23): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 24): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 25): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/layers.py', 191): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/layers.py', 44): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 26): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 283): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 284): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/callback.py', 285): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 28): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 92): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 93): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 94): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/torch_core.py', 95): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 342): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 124): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 126): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 128): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 130): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 131): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 120): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 121): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 132): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 135): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 136): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 137): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 119): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 120): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 121): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 343): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 362): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 363): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 364): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 367): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 368): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 369): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 369): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 258): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 253): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 254): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/data_block.py', 372): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/core.py', 282): 1,
#  ('/Users/yang.zhang/git/fastai/fastai/basic_train.py', 370): 1}

# %%
# tracer.results().counts
